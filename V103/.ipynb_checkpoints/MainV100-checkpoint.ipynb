# %%
import pandas as pd
import csv

# %%
#This is the header for the East inventory
header= ["DC_Code","DC_Name","barcode","stock_no","description_1","description_2","category","category_name","total_inventory","shipping_qty","allocate_qty","blocked_qty","available_qty","arrival_qty","expected_inventory","order_point","unit","uodate_date"]

#The following adds the header above to the first line of the file.
with open("./input/Inventory_East.csv",newline='', encoding="shift_jis_2004") as f:
    r = csv.reader(f)
    data = [line for line in r]
with open('./input/Inventory_EastWithHeader.csv','w',newline='',encoding="shift_jis_2004") as f:
    w = csv.writer(f)
    w.writerow(header)
    w.writerows(data)

# %%
df_inv_east = pd.read_csv("./input/Inventory_EastWithHeader.csv", usecols=["DC_Name","stock_no","available_qty"])
df_inv_east.columns=["InverntoryName",  "Item code", "NumItemsAvailable"] #renames the columns

# %%
#The following adds the header above to the first line of the file.
with open("./input/Inventory_West.csv",newline='', encoding="shift_jis_2004") as f:
    r = csv.reader(f)
    data = [line for line in r]
with open('./input/Inventory_WestWithHeader.csv','w',newline='',encoding="shift_jis_2004") as f:
    w = csv.writer(f)
    w.writerow(header)
    w.writerows(data)

# %%
df_inv_west = pd.read_csv("./input/Inventory_WestWithHeader.csv", usecols=["DC_Name","stock_no","available_qty"])
df_inv_west.columns=["InverntoryName",  "Item code", "NumItemsAvailable"] #renames the columns

# %% [markdown]
# Order_list IMPROT

# %%
#This is the header for the Shipping order file
header_order = ["Shipping_Order_No","Voucher_Class","Order_Date","Delivery_Date","Planed_Ship_Date","DC_Code","DC_Name","Customer_Code","Customer_Name1","Customer_Name2","Data_11","Data_12","Data_13","Data_14","Customer_Zip_Code","Customer_address1","Customer_address2","Customer_TEL","Customer_FAX","Order_No","Transport_Company","Receiver_Code","Receiver_Name1","Receiver_Name2","Data_25","Data_26","Data_27","Data_28","Receiver_Zip_Code","Receiver_address1","Receiver_address2","Receiver_TEL","Receiver_FAX","Consumption_TAX","Data_35","Data_36","Mail_address","Point","Data_39","SAP_Shipping_No","Data_41","Working_Condition","Balance","Data_44","Data_45","Data_46","Data_47","Update_date","Detail_No","Data_50","Stock_No","BarCode","Location","Description1","Description2","Pcs_Per_case","Case_No","Quantity","Units","Lot1","Lot2","Status_Code","Status","Data_64","Data_65","Data_66","Warranty","Data_68","Data_69","Detail_Update_date"]

#The following adds the header above to the first line of the file.
with open("./input/Order.csv",newline='', encoding="shift_jis_2004") as f:
    r = csv.reader(f)
    data = [line for line in r]
with open('./input/OrderWithHeader.csv','w',newline='',encoding="shift_jis_2004") as f:
    w = csv.writer(f)
    w.writerow(header_order)
    w.writerows(data)

# %%
df_order = pd.read_csv("./input/OrderWithHeader.csv", encoding="shift_jis_2004",converters={'Receiver_Zip_Code': lambda x: x.strip('”'),'Shipping_Order_No': lambda x: x.strip('”'),'Stock_No': lambda x: x.strip('”'),'Quantity': lambda x: int(x.strip('”')) })
df_order = df_order.rename(columns={'Stock_No': 'item code', 'Quantity' : 'NumItemsNeeded'}) #I will just rename these columns since at earler versions of the code these names were used and changing them in the code now, might alter the dynamics. 
df_order
# Out:
#    Shipping_Order_No Voucher_Class             Order_Date Delivery_Date  \
# 0         2001769876            ””  ”2020/04/13 22:07:52”  ”2020/04/13”
# 1         2001771962            ””  ”2020/04/14 18:22:16”  ”2020/04/14”
# 2         2001771962            ””  ”2020/04/14 18:22:16”  ”2020/04/14”
# 3         2001771962            ””  ”2020/04/14 18:22:16”  ”2020/04/14”
# 4         2001771962            ””  ”2020/04/14 18:22:16”  ”2020/04/14”
# 5         2001771962            ””  ”2020/04/14 18:22:16”  ”2020/04/14”
# 6         2001771962            ””  ”2020/04/14 18:22:16”  ”2020/04/14”
# 7         2001771962            ””  ”2020/04/14 18:22:16”  ”2020/04/14”
# 8         2001771962            ””  ”2020/04/14 18:22:16”  ”2020/04/14”
# 9         2001771962            ””  ”2020/04/14 18:22:16”  ”2020/04/14”
# 10        2001771984            ””  ”2020/04/14 18:49:11”  ”2020/04/14”
# 11        2001771984            ””  ”2020/04/14 18:49:11”  ”2020/04/14”
# 12        2001771999            ””  ”2020/04/14 19:01:14”  ”2020/04/14”
# 13        2001772059            ””  ”2020/04/14 19:57:02”  ”2020/04/14”
# 14        2001772463            ””  ”2020/04/14 22:48:37”  ”2020/04/14”
# 15        2001772492            ””  ”2020/04/14 22:59:57”  ”2020/04/14”
# 16        2001772492            ””  ”2020/04/14 22:59:57”  ”2020/04/14”
# 17        2001772492            ””  ”2020/04/14 22:59:57”  ”2020/04/14”
# 18        2001772492            ””  ”2020/04/14 22:59:57”  ”2020/04/14”
# 19        2001772492            ””  ”2020/04/14 22:59:57”  ”2020/04/14”
# 20        2001772492            ””  ”2020/04/14 22:59:57”  ”2020/04/14”
# 21        2001772492            ””  ”2020/04/14 22:59:57”  ”2020/04/14”
# 22        2001772492            ””  ”2020/04/14 22:59:57”  ”2020/04/14”
# 23        2001772492            ””  ”2020/04/14 22:59:57”  ”2020/04/14”
# 24        2001772492            ””  ”2020/04/14 22:59:57”  ”2020/04/14”
# 25        2001772492            ””  ”2020/04/14 22:59:57”  ”2020/04/14”
# 26        2001772004            ””  ”2020/04/14 19:09:44”  ”2020/04/14”
# 27        2001772004            ””  ”2020/04/14 19:09:44”  ”2020/04/14”
# 28        2001772004            ””  ”2020/04/14 19:09:44”  ”2020/04/14”
# 29        2001772007            ””  ”2020/04/14 19:12:33”  ”2020/04/14”
# 30        2001772007            ””  ”2020/04/14 19:12:33”  ”2020/04/14”
# 31        2001772085            ””  ”2020/04/14 20:19:48”  ”2020/04/14”
# 32        2001772163            ””  ”2020/04/14 21:29:28”  ”2020/04/14”
# 33        2001772163            ””  ”2020/04/14 21:29:28”  ”2020/04/14”
# 34        2001772163            ””  ”2020/04/14 21:29:28”  ”2020/04/14”
# 35        2001772163            ””  ”2020/04/14 21:29:28”  ”2020/04/14”
# 36        2001772163            ””  ”2020/04/14 21:29:28”  ”2020/04/14”
# 37        2001772163            ””  ”2020/04/14 21:29:28”  ”2020/04/14”
# 38        2001772163            ””  ”2020/04/14 21:29:28”  ”2020/04/14”
# 39        2001772707            ””  ”2020/04/15 03:24:49”  ”2020/04/15”
# 40        2001772707            ””  ”2020/04/15 03:24:49”  ”2020/04/15”
# 41        2001772740            ””  ”2020/04/15 07:51:26”  ”2020/04/15”
# 42        2001772740            ””  ”2020/04/15 07:51:26”  ”2020/04/15”
# 43        2001772740            ””  ”2020/04/15 07:51:26”  ”2020/04/15”
# 44        2001772550            ””  ”2020/04/15 00:00:40”  ”2020/04/15”
# 45        2001772649            ””  ”2020/04/15 00:27:34”  ”2020/04/15”
# 46        2001772649            ””  ”2020/04/15 00:27:34”  ”2020/04/15”
# 47        2001772649            ””  ”2020/04/15 00:27:34”  ”2020/04/15”
# 48        2001772712            ””  ”2020/04/15 04:32:50”  ”2020/04/15”
# 49        2001772745            ””  ”2020/04/15 07:55:57”  ”2020/04/15”
# 50        2001772755            ””  ”2020/04/15 08:12:38”  ”2020/04/15”
# 51        2001772755            ””  ”2020/04/15 08:12:38”  ”2020/04/15”
# 52        2001772755            ””  ”2020/04/15 08:12:38”  ”2020/04/15”
# 53        2001772755            ””  ”2020/04/15 08:12:38”  ”2020/04/15”
#
#    Planed_Ship_Date DC_Code DC_Name Customer_Code       Customer_Name1  \
# 0                ””      ””      ””            ””             ”フリーランス”
# 1                ””      ””      ””            ””          ”Sea　gull.”
# 2                ””      ””      ””            ””          ”Sea　gull.”
# 3                ””      ””      ””            ””          ”Sea　gull.”
# 4                ””      ””      ””            ””          ”Sea　gull.”
# 5                ””      ””      ””            ””          ”Sea　gull.”
# 6                ””      ””      ””            ””          ”Sea　gull.”
# 7                ””      ””      ””            ””          ”Sea　gull.”
# 8                ””      ””      ””            ””          ”Sea　gull.”
# 9                ””      ””      ””            ””          ”Sea　gull.”
# 10               ””      ””      ””            ””               ”シャルム”
# 11               ””      ””      ””            ””               ”シャルム”
# 12               ””      ””      ””            ””       ”ボディケア　縁-えにし-”
# 13               ””      ””      ””            ””              ”庄司 悦子”
# 14               ””      ””      ””            ””                ”悠心堂”
# 15               ””      ””      ””            ””             ”CLOVER”
# 16               ””      ””      ””            ””             ”CLOVER”
# 17               ””      ””      ””            ””             ”CLOVER”
# 18               ””      ””      ””            ””             ”CLOVER”
# 19               ””      ””      ””            ””             ”CLOVER”
# 20               ””      ””      ””            ””             ”CLOVER”
# 21               ””      ””      ””            ””             ”CLOVER”
# 22               ””      ””      ””            ””             ”CLOVER”
# 23               ””      ””      ””            ””             ”CLOVER”
# 24               ””      ””      ””            ””             ”CLOVER”
# 25               ””      ””      ””            ””             ”CLOVER”
# 26               ””      ””      ””            ””               ”阪本恵美”
# 27               ””      ””      ””            ””               ”阪本恵美”
# 28               ””      ””      ””            ””               ”阪本恵美”
# 29               ””      ””      ””            ””          ”I&B　NaFaS”
# 30               ””      ””      ””            ””          ”I&B　NaFaS”
# 31               ””      ””      ””            ””              ”小林ひろみ”
# 32               ””      ””      ””            ””              ”宮島つくみ”
# 33               ””      ””      ””            ””              ”宮島つくみ”
# 34               ””      ””      ””            ””              ”宮島つくみ”
# 35               ””      ””      ””            ””              ”宮島つくみ”
# 36               ””      ””      ””            ””              ”宮島つくみ”
# 37               ””      ””      ””            ””              ”宮島つくみ”
# 38               ””      ””      ””            ””              ”宮島つくみ”
# 39               ””      ””      ””            ””                ”day”
# 40               ””      ””      ””            ””                ”day”
# 41               ””      ””      ””            ””            ”coffret”
# 42               ””      ””      ””            ””            ”coffret”
# 43               ””      ””      ””            ””            ”coffret”
# 44               ””      ””      ””            ””       ”Nagel_Lottie”
# 45               ””      ””      ””            ””  ”トータルボディケアサロン　Bean”
# 46               ””      ””      ””            ””  ”トータルボディケアサロン　Bean”
# 47               ””      ””      ””            ””  ”トータルボディケアサロン　Bean”
# 48               ””      ””      ””            ””         ”株式会社Amazio”
# 49               ””      ””      ””            ””               ”Aaty”
# 50               ””      ””      ””            ””      ”BarBer kayama”
# 51               ””      ””      ””            ””      ”BarBer kayama”
# 52               ””      ””      ””            ””      ”BarBer kayama”
# 53               ””      ””      ””            ””      ”BarBer kayama”
#
#    Customer_Name2  ... Lot2 Status_Code Status Data_64 Data_65 Data_66  \
# 0              ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 1              ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 2              ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 3              ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 4              ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 5              ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 6              ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 7              ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 8              ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 9              ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 10             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 11             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 12             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 13             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 14             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 15             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 16             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 17             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 18             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 19             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 20             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 21             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 22             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 23             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 24             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 25             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 26             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 27             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 28             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 29             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 30             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 31             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 32             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 33             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 34             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 35             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 36             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 37             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 38             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 39             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 40             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 41             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 42             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 43             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 44             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 45             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 46             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 47             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 48             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 49             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 50             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 51             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 52             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 53             ””  ...   ””          ””     ””      ””      ””  ”BG00”
#
#    Warranty Data_68 Data_69 Detail_Update_date
# 0      ”なし”      ””      ””                 ””
# 1      ”なし”      ””      ””                 ””
# 2      ”なし”      ””      ””                 ””
# 3      ”なし”      ””      ””                 ””
# 4      ”なし”      ””      ””                 ””
# 5      ”なし”      ””      ””                 ””
# 6      ”なし”      ””      ””                 ””
# 7      ”なし”      ””      ””                 ””
# 8      ”なし”      ””      ””                 ””
# 9      ”なし”      ””      ””                 ””
# 10     ”なし”      ””      ””                 ””
# 11     ”なし”      ””      ””                 ””
# 12     ”なし”      ””      ””                 ””
# 13     ”1年”      ””      ””                 ””
# 14     ”なし”      ””      ””                 ””
# 15     ”なし”      ””      ””                 ””
# 16     ”なし”      ””      ””                 ””
# 17     ”なし”      ””      ””                 ””
# 18     ”なし”      ””      ””                 ””
# 19     ”なし”      ””      ””                 ””
# 20     ”なし”      ””      ””                 ””
# 21     ”なし”      ””      ””                 ””
# 22     ”なし”      ””      ””                 ””
# 23     ”なし”      ””      ””                 ””
# 24     ”なし”      ””      ””                 ””
# 25     ”なし”      ””      ””                 ””
# 26     ”なし”      ””      ””                 ””
# 27     ”なし”      ””      ””                 ””
# 28     ”なし”      ””      ””                 ””
# 29     ”なし”      ””      ””                 ””
# 30     ”なし”      ””      ””                 ””
# 31     ”なし”      ””      ””                 ””
# 32     ”なし”      ””      ””                 ””
# 33     ”なし”      ””      ””                 ””
# 34     ”なし”      ””      ””                 ””
# 35     ”なし”      ””      ””                 ””
# 36     ”なし”      ””      ””                 ””
# 37     ”なし”      ””      ””                 ””
# 38     ”なし”      ””      ””                 ””
# 39     ”なし”      ””      ””                 ””
# 40     ”なし”      ””      ””                 ””
# 41     ”なし”      ””      ””                 ””
# 42     ”なし”      ””      ””                 ””
# 43     ”なし”      ””      ””                 ””
# 44     ”なし”      ””      ””                 ””
# 45     ”なし”      ””      ””                 ””
# 46     ”なし”      ””      ””                 ””
# 47     ”なし”      ””      ””                 ””
# 48     ”1年”      ””      ””                 ””
# 49     ”1年”      ””      ””                 ””
# 50     ”なし”      ””      ””                 ””
# 51     ”なし”      ””      ””                 ””
# 52     ”なし”      ””      ””                 ””
# 53     ”なし”      ””      ””                 ””
#
# [54 rows x 70 columns]

# %%
df_postal = pd.read_csv("./input/Zip_Code East West List.csv", converters={'Zip_Code 3degit': lambda x: str(x)}, usecols= ["Zip_Code 3degit", "East/West"]) #Reading the Post code file
df_postal.columns=["PostCode", "East_West"] #renames the columns
df_postal = df_postal.drop_duplicates(keep='first',ignore_index = True)

# %% [markdown]
# Let's import these data into a class for better access

# %%
class order:
    def __init__(self, order_num, zipcode, items): 
        self.order_num = order_num 
        self.zipcode = zipcode
        self.items = items #items is gonna be a list of class item

# %%
OrderNumbers = df_order["Shipping_Order_No"].unique().tolist() #A list with all the order numbers inside it (unique)
zipcodes = df_order["Receiver_Zip_Code"].unique().tolist() #A list with all the Zipcodes inside it (unique) not necessarily the same size as OrderNumbers

# %%
OrderNumbers
# Out:
# ['2001769876',
#  '2001771962',
#  '2001771984',
#  '2001771999',
#  '2001772059',
#  '2001772463',
#  '2001772492',
#  '2001772004',
#  '2001772007',
#  '2001772085',
#  '2001772163',
#  '2001772707',
#  '2001772740',
#  '2001772550',
#  '2001772649',
#  '2001772712',
#  '2001772745',
#  '2001772755']

# %%
List_of_index_orders = [] #This list will contain the indexes (i.e. rows) for each shipping number. 
for i in OrderNumbers:
    List_of_index_orders.append(df_order.index[df_order["Shipping_Order_No"] == i].tolist())

# %%
#This function create the list_items
def get_items(List_of_index_orders):    
    availibility = False #default values of availibility
    inv_loc = "unknown" #default values of location
    
    list_items = list()
    temp = list()
    for i in range(len(List_of_index_orders)):
        for j in  List_of_index_orders[i]:
            temp.append([df_order.at[j,'item code'],df_order.at[j,'NumItemsNeeded'],availibility,inv_loc,\
                        [df_order.at[j,'Voucher_Class'],df_order.at[j,'Order_Date'],df_order.at[j,'Delivery_Date'],df_order.at[j,'Planed_Ship_Date'],\
                        df_order.at[j,'DC_Code'],df_order.at[j,'DC_Name'],df_order.at[j,'Customer_Code'],df_order.at[j,'Customer_Name1'],\
                        df_order.at[j,'Customer_Name2'],df_order.at[j,'Data_11'],df_order.at[j,'Data_12'],df_order.at[j,'Data_13'],\
                        df_order.at[j,'Data_14'],df_order.at[j,'Customer_Zip_Code'],df_order.at[j,'Customer_address1'],df_order.at[j,'Customer_address2'],\
                        df_order.at[j,'Customer_TEL'],df_order.at[j,'Customer_FAX'],df_order.at[j,'Order_No'],df_order.at[j,'Transport_Company'],\
                        df_order.at[j,'Receiver_Code'],df_order.at[j,'Receiver_Name1'],df_order.at[j,'Receiver_Name2'],df_order.at[j,'Data_25'],\
                        df_order.at[j,'Data_26'],df_order.at[j,'Data_27'],df_order.at[j,'Data_28'],\
                        df_order.at[j,'Receiver_address1'],df_order.at[j,'Receiver_address2'],df_order.at[j,'Receiver_TEL'],df_order.at[j,'Receiver_FAX'],\
                        df_order.at[j,'Consumption_TAX'],df_order.at[j,'Data_35'],df_order.at[j,'Data_36'],df_order.at[j,'Mail_address'],\
                        df_order.at[j,'Point'],df_order.at[j,'Data_39'],df_order.at[j,'SAP_Shipping_No'],df_order.at[j,'Data_41'],\
                        df_order.at[j,'Working_Condition'],df_order.at[j,'Balance'],df_order.at[j,'Data_44'],df_order.at[j,'Data_45'],\
                        df_order.at[j,'Data_46'],df_order.at[j,'Data_47'],df_order.at[j,'Update_date'],df_order.at[j,'Detail_No'],\
                        df_order.at[j,'Data_50'],df_order.at[j,'BarCode'],df_order.at[j,'Location'],\
                        df_order.at[j,'Description1'],df_order.at[j,'Description2'],df_order.at[j,'Pcs_Per_case'],df_order.at[j,'Case_No'],\
                        df_order.at[j,'Units'],df_order.at[j,'Lot1'],df_order.at[j,'Lot2'],\
                        df_order.at[j,'Status_Code'],df_order.at[j,'Status'],df_order.at[j,'Data_64'],df_order.at[j,'Data_65'],\
                        df_order.at[j,'Data_66'],df_order.at[j,'Warranty'],df_order.at[j,'Data_68'],df_order.at[j,'Data_69'],\
                        df_order.at[j,'Detail_Update_date']]   ]) #these other information has to be in a list because I have to write down an _ later on
            
        list_items.append(temp.copy())
        temp.clear()
    return list_items

# %%
list_items = get_items(List_of_index_orders)

# %%
orders = list()

# Better to put an if loop here to make sure len(List_of_index_orders) = len(list_items)
for i in range(len(List_of_index_orders)):
    OrderNumber = OrderNumbers[i]
    Zipcode = df_order.at[List_of_index_orders[i][0],"Receiver_Zip_Code"]
    Items = list_items[i]
    orders.append(order(OrderNumber,Zipcode,Items))

# %%
orders[1].items
# Out:
# [['HD-3113N',
#   1,
#   False,
#   'unknown',
#   ['””',
#    '”2020/04/14 18:22:16”',
#    '”2020/04/14”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”Sea\u3000gull.”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”広島県 山県郡北広島町春木９６０−６”',
#    '””',
#    '””',
#    '””',
#    '”S001418807”',
#    '””',
#    '””',
#    '”Sea\u3000gull.”',
#    '”平江\u3000三恵子”',
#    '”佐川急便/千葉物流センタ01/7378//BG”',
#    '””',
#    '”平江\u3000三恵子”',
#    '”様”',
#    '”広島県 山県郡北広島町春木960-7”',
#    '””',
#    '”0826720324”',
#    '””',
#    '”666”',
#    '””',
#    '””',
#    '”hirae1031@hi.enjoy.ne.jp”',
#    '”756”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”/440”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”4954835334815”',
#    '””',
#    '”オルディーブ アディクシー オキシダン 6% 1000ml【医薬部外品】”',
#    '””',
#    '””',
#    '””',
#    '”PC”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”BG00”',
#    '”なし”',
#    '””',
#    '””',
#    '””']],
#  ['HC-4561N',
#   1,
#   False,
#   'unknown',
#   ['””',
#    '”2020/04/14 18:22:16”',
#    '”2020/04/14”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”Sea\u3000gull.”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”広島県 山県郡北広島町春木９６０−６”',
#    '””',
#    '””',
#    '””',
#    '”S001418807”',
#    '””',
#    '””',
#    '”Sea\u3000gull.”',
#    '”平江\u3000三恵子”',
#    '”佐川急便/千葉物流センタ01/7378//BG”',
#    '””',
#    '”平江\u3000三恵子”',
#    '”様”',
#    '”広島県 山県郡北広島町春木960-7”',
#    '””',
#    '”0826720324”',
#    '””',
#    '”666”',
#    '””',
#    '””',
#    '”hirae1031@hi.enjoy.ne.jp”',
#    '”756”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”/440”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”4954835334525”',
#    '””',
#    '”オルディーブ アディクシー サファイア9 80g【医薬部外品】”',
#    '””',
#    '””',
#    '””',
#    '”PC”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”BG00”',
#    '”なし”',
#    '””',
#    '””',
#    '””']],
#  ['HC-4560N',
#   1,
#   False,
#   'unknown',
#   ['””',
#    '”2020/04/14 18:22:16”',
#    '”2020/04/14”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”Sea\u3000gull.”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”広島県 山県郡北広島町春木９６０−６”',
#    '””',
#    '””',
#    '””',
#    '”S001418807”',
#    '””',
#    '””',
#    '”Sea\u3000gull.”',
#    '”平江\u3000三恵子”',
#    '”佐川急便/千葉物流センタ01/7378//BG”',
#    '””',
#    '”平江\u3000三恵子”',
#    '”様”',
#    '”広島県 山県郡北広島町春木960-7”',
#    '””',
#    '”0826720324”',
#    '””',
#    '”666”',
#    '””',
#    '””',
#    '”hirae1031@hi.enjoy.ne.jp”',
#    '”756”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”/440”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”4954835334518”',
#    '””',
#    '”オルディーブ アディクシー サファイア13 80g【医薬部外品】”',
#    '””',
#    '””',
#    '””',
#    '”PC”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”BG00”',
#    '”なし”',
#    '””',
#    '””',
#    '””']],
#  ['HD-0079P',
#   1,
#   False,
#   'unknown',
#   ['””',
#    '”2020/04/14 18:22:16”',
#    '”2020/04/14”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”Sea\u3000gull.”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”広島県 山県郡北広島町春木９６０−６”',
#    '””',
#    '””',
#    '””',
#    '”S001418807”',
#    '””',
#    '””',
#    '”Sea\u3000gull.”',
#    '”平江\u3000三恵子”',
#    '”佐川急便/千葉物流センタ01/7378//BG”',
#    '””',
#    '”平江\u3000三恵子”',
#    '”様”',
#    '”広島県 山県郡北広島町春木960-7”',
#    '””',
#    '”0826720324”',
#    '””',
#    '”666”',
#    '””',
#    '””',
#    '”hirae1031@hi.enjoy.ne.jp”',
#    '”756”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”/440”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”4560441262956”',
#    '””',
#    '”sroloc OX6% (エスロロック 2剤) 2000ml【医薬部外品】”',
#    '””',
#    '””',
#    '””',
#    '”PC”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”BG00”',
#    '”なし”',
#    '””',
#    '””',
#    '””']],
#  ['HC-3214P',
#   2,
#   False,
#   'unknown',
#   ['””',
#    '”2020/04/14 18:22:16”',
#    '”2020/04/14”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”Sea\u3000gull.”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”広島県 山県郡北広島町春木９６０−６”',
#    '””',
#    '””',
#    '””',
#    '”S001418807”',
#    '””',
#    '””',
#    '”Sea\u3000gull.”',
#    '”平江\u3000三恵子”',
#    '”佐川急便/千葉物流センタ01/7378//BG”',
#    '””',
#    '”平江\u3000三恵子”',
#    '”様”',
#    '”広島県 山県郡北広島町春木960-7”',
#    '””',
#    '”0826720324”',
#    '””',
#    '”666”',
#    '””',
#    '””',
#    '”hirae1031@hi.enjoy.ne.jp”',
#    '”756”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”/440”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”4573191231028”',
#    '””',
#    '”sroloc N-7D (エスロロック ナチュラル7ディープブラージュ) 120”',
#    '””',
#    '””',
#    '””',
#    '”PC”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”BG00”',
#    '”なし”',
#    '””',
#    '””',
#    '””']],
#  ['HC-3215P',
#   2,
#   False,
#   'unknown',
#   ['””',
#    '”2020/04/14 18:22:16”',
#    '”2020/04/14”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”Sea\u3000gull.”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”広島県 山県郡北広島町春木９６０−６”',
#    '””',
#    '””',
#    '””',
#    '”S001418807”',
#    '””',
#    '””',
#    '”Sea\u3000gull.”',
#    '”平江\u3000三恵子”',
#    '”佐川急便/千葉物流センタ01/7378//BG”',
#    '””',
#    '”平江\u3000三恵子”',
#    '”様”',
#    '”広島県 山県郡北広島町春木960-7”',
#    '””',
#    '”0826720324”',
#    '””',
#    '”666”',
#    '””',
#    '””',
#    '”hirae1031@hi.enjoy.ne.jp”',
#    '”756”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”/440”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”4573191231011”',
#    '””',
#    '”sroloc N-9D (エスロロック ナチュラル9ディープブラージュ) 120”',
#    '””',
#    '””',
#    '””',
#    '”PC”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”BG00”',
#    '”なし”',
#    '””',
#    '””',
#    '””']],
#  ['TZ-0410P',
#   1,
#   False,
#   'unknown',
#   ['””',
#    '”2020/04/14 18:22:16”',
#    '”2020/04/14”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”Sea\u3000gull.”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”広島県 山県郡北広島町春木９６０−６”',
#    '””',
#    '””',
#    '””',
#    '”S001418807”',
#    '””',
#    '””',
#    '”Sea\u3000gull.”',
#    '”平江\u3000三恵子”',
#    '”佐川急便/千葉物流センタ01/7378//BG”',
#    '””',
#    '”平江\u3000三恵子”',
#    '”様”',
#    '”広島県 山県郡北広島町春木960-7”',
#    '””',
#    '”0826720324”',
#    '””',
#    '”666”',
#    '””',
#    '””',
#    '”hirae1031@hi.enjoy.ne.jp”',
#    '”756”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”/440”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”4560441266176”',
#    '””',
#    '”Baby Touch フェイシャルコットン Mサイズ（60×80mm/500枚入”',
#    '””',
#    '””',
#    '””',
#    '”PC”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”BG00”',
#    '”なし”',
#    '””',
#    '””',
#    '””']],
#  ['HC-4570N',
#   1,
#   False,
#   'unknown',
#   ['””',
#    '”2020/04/14 18:22:16”',
#    '”2020/04/14”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”Sea\u3000gull.”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”広島県 山県郡北広島町春木９６０−６”',
#    '””',
#    '””',
#    '””',
#    '”S001418807”',
#    '””',
#    '””',
#    '”Sea\u3000gull.”',
#    '”平江\u3000三恵子”',
#    '”佐川急便/千葉物流センタ01/7378//BG”',
#    '””',
#    '”平江\u3000三恵子”',
#    '”様”',
#    '”広島県 山県郡北広島町春木960-7”',
#    '””',
#    '”0826720324”',
#    '””',
#    '”666”',
#    '””',
#    '””',
#    '”hirae1031@hi.enjoy.ne.jp”',
#    '”756”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”/440”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”4954835334617”',
#    '””',
#    '”オルディーブ アディクシー エメラルド13 80g【医薬部外品】”',
#    '””',
#    '””',
#    '””',
#    '”PC”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”BG00”',
#    '”なし”',
#    '””',
#    '””',
#    '””']],
#  ['HC-3216P',
#   2,
#   False,
#   'unknown',
#   ['””',
#    '”2020/04/14 18:22:16”',
#    '”2020/04/14”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”Sea\u3000gull.”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”広島県 山県郡北広島町春木９６０−６”',
#    '””',
#    '””',
#    '””',
#    '”S001418807”',
#    '””',
#    '””',
#    '”Sea\u3000gull.”',
#    '”平江\u3000三恵子”',
#    '”佐川急便/千葉物流センタ01/7378//BG”',
#    '””',
#    '”平江\u3000三恵子”',
#    '”様”',
#    '”広島県 山県郡北広島町春木960-7”',
#    '””',
#    '”0826720324”',
#    '””',
#    '”666”',
#    '””',
#    '””',
#    '”hirae1031@hi.enjoy.ne.jp”',
#    '”756”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”/440”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”4573191231035”',
#    '””',
#    '”sroloc N-6D (エスロロック ナチュラル6ディープブラージュ) 120”',
#    '””',
#    '””',
#    '””',
#    '”PC”',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '””',
#    '”BG00”',
#    '”なし”',
#    '””',
#    '””',
#    '””']]]

# %% [markdown]
# Importing done! let's define the functions we need.

# %%
def remove_duplicates(order): #Check for any duplicates of items of an order
    duplicates = list()
    for i in range(len(order.items)):
        for j in range(i+1,len(order.items)):
            if(order.items[i][0] == order.items[j][0]):
                if(order.items[j] not in duplicates):
                    order.items[i][1] = order.items[i][1] + order.items[j][1]
                    duplicates.append(order.items[j])
    for item in duplicates:
        print("removing", item)
        order.items.remove(item)

# %%
def EastOrWest(order):
    FirstThreeDigit = str(order.zipcode)[:3] #gets the first three digits of input ZipCode
    if(df_postal["PostCode"].tolist().count(FirstThreeDigit)>0):
        #print("Code exists in the list.")
        index_postalCode = df_postal.index[df_postal['PostCode'] == FirstThreeDigit].tolist()[0]    
        if(df_postal.at[index_postalCode,'East_West'].strip()=="East"): #strip() removes the spaces at the begining and the end
            #print("Zipcode is for East.")
            return 1 # returns 1 for East and 0 for West
        elif(df_postal.at[index_postalCode,'East_West'].strip()=="West"):
            #print("Zipcode is for West.")
            return 0 # returns 1 for East and 0 for West
    else:
        #raise NameError('First three digits', str(FirstThreeDigit), 'was not found in postal code list.')
        print('First three digits', str(FirstThreeDigit), 'was not found in postal code list. \nSending order number ',order.order_num,'to east.')
        return 1

# %%
def update_inv(order): #this function will updates inventory 
    for item in order.items:
        if(item[3] == 'East'): #item[3] is the location  variable
            Index_item_inv_east = df_inv_east.index[df_inv_east['Item code'] == item[0]].tolist()[0] #index of the item in inventory list 
            df_inv_east.at[Index_item_inv_east , 'NumItemsAvailable'] = df_inv_east.at[Index_item_inv_east , 'NumItemsAvailable'] - item[1]
        
        elif(item[3] == 'West'): #item[3] is the location  variable
            Index_item_inv_west = df_inv_west.index[df_inv_west['Item code'] == item[0]].tolist()[0] #index of the item in inventory list 
            df_inv_west.at[Index_item_inv_west , 'NumItemsAvailable'] = df_inv_west.at[Index_item_inv_west , 'NumItemsAvailable'] - item[1]
        else:
            raise NameError("something is wrong with updating inv for order:", order.order_num)

# %%
def Item_available_east(Item_code, Num_items_ordered):
    List_of_items_inventory = df_inv_east['Item code'].tolist()
    if(Item_code in List_of_items_inventory):
        Inv_index_item = df_inv_east.index[df_inv_east['Item code'] == Item_code].tolist()[0] #index of the item in inventory list 
        #print("Index of item ", Item_code, " is ",Inv_index_item,"in inventory list.")
        Num_avil_item = df_inv_east.at[Inv_index_item,'NumItemsAvailable'] #number of available items in inventory
        #print("There are ", Num_avil_item, " items available and", Num_items_ordered  ,"needed for item", Item_code)
        
        if(Num_avil_item - Num_items_ordered >= 0): #checks if there are enough items in the inventory.
            #print("Enough items are available for item ", Item_code,". \nNow there are ", Num_avil_item - Num_items_ordered, "left in inventory." )
            return 1
        else:
            #print("There is not enough items in East inventory",Item_code,".\nMissing number =", Num_avil_item - Num_items_ordered)
            return 0
        
    else:
        Items_not_in_inv_east.append(Item_code)
        print('One items', Item_code, 'was not found in east inventory.')

# %%
def check_inv_east(order):
    for item in order.items:
        if(item[2] == False):
            if(Item_available_east(item[0],item[1])): #item[0] = Code, item[1] = Num_items_ordered
                item[2] = True #availability
                item[3] = "East" #Location
    if(all( availability == 1 for (_, _, availability,_,_) in order.items)):
        return 1 #Some or all items are avaible in East_inv 
    else:
        return 0

# %%
def Item_available_west(Item_code, Num_items_ordered):
    List_of_items_inventory = df_inv_west['Item code'].tolist()
    if(Item_code in List_of_items_inventory):
        Inv_index_item = df_inv_west.index[df_inv_west['Item code'] == Item_code].tolist()[0] #index of the item in inventory list 
        #print("Index of item ", Item_code, " is ",Inv_index_item,"in inventory list.")
        Num_avil_item = df_inv_west.at[Inv_index_item,'NumItemsAvailable'] #number of available items in inventory
        #print("There are ", Num_avil_item, " items available and", Num_items_ordered  ,"needed for item", Item_code)
        
        if(Num_avil_item - Num_items_ordered >= 0): #checks if there are enough items in the inventory.
            #print("Enough items are available for item ", Item_code,". \nNow there are ", Num_avil_item - Num_items_ordered, "left in inventory." )
            return 1
        else:
            #print("There is not enough items in West inventory",Item_code,".\nMissing number =", Num_avil_item - Num_items_ordered)
            return 0
        
    else:       
        Items_not_in_inv_east.append(Item_code)
        print('One items', Item_code, 'was not found in west inventory.')

# %%
def check_inv_west(order):
    for item in order.items:
        if(item[2] == False):
            if(Item_available_west(item[0],item[1])): #item[0] = Code, item[1] = Num_items_ordered
                item[2] = True #availability
                item[3] = "West" #Location
    if(all( availability == 1 for (_, _, availability,_,_) in order.items)):
        return 1 #Some or all items are avaible in East_inv 
    else:
        return 0

# %%
def split_order(order):
    original_item2be_split = list()
    for item in order.items: #sends the items one by one
        if(item[2] == False): # only items that were not avaiable in East will go through 
            if(item[0] in df_inv_east['Item code'].tolist()): #checks if the itemcode exists in inv
                Index_item_inv_east = df_inv_east.index[df_inv_east['Item code'] == item[0]].tolist()[0] #index of the item in east inventory 
                if(df_inv_east.at[Index_item_inv_east , 'NumItemsAvailable'] == 0): #checks if the order needs to be split
                    #No need to split, no items in east inv.
                    if(Item_available_west(item[0],item[1])): #item[0] = Code, item[1] = Num_items_ordered
                        item[2] = True #availability
                        item[3] = "West" #Location
                    else:
                        print("Not enough items in both inventory for item",item,"in order",order.order_num)
                elif(item[0] not in df_inv_west['Item code'].tolist()):
                    print("item does not exist in west inv")

                else:
                    if(item[0] in df_inv_west['Item code'].tolist()): #checks if item exists in west inv
                        Index_item_inv_west = df_inv_west.index[df_inv_west['Item code'] == item[0]].tolist()[0] #index of the item in west inventory 
                        if(df_inv_east.at[Index_item_inv_east , 'NumItemsAvailable'] + df_inv_west.at[Index_item_inv_west , 'NumItemsAvailable'] >= item[1]):
                            #if item in East_inv + West_inv greater than quantity needed; 

                            #there are enough items in both inventories
                            new_item_east = [item[0], df_inv_east.at[Index_item_inv_east , 'NumItemsAvailable'], True, "East", item[4]]
                            new_item_west = [item[0], item[1]-df_inv_east.at[Index_item_inv_west , 'NumItemsAvailable'], True, "West", item[4]]
                            print("removing the parent order and replacing it with split order for order number:", order.order_num, item[0])
                            original_item2be_split.append(item)
                            order.items.append(new_item_east)
                            order.items.append(new_item_west)
                    else:
                        print("item",item[0],"doesnot exist in west(split order). CANNOT BE SPLIT")
                            
            else: #does not exist in East inv
                print("item",item[0],"doesnot exist in east in split order.")
                
    for item in original_item2be_split:
        order.items.remove(item)
                    
    return order

# %% [markdown]
# ______________________________________Main___________________________________________

# %%
Complete_orders = list()
Incomplete_orders = list()
Splited_orders = list()

Items_not_in_inv_east = list()
Items_not_in_inv_west = list()

# %%
for order in orders:
    remove_duplicates(order) #merges duplicated items in an order
    if(EastOrWest(order)):
        #East
        if(check_inv_east(order)):
            #print("All items for order",order.order_num," are avaible. All in East.")
            Complete_orders.append(order)
            update_inv(order)
        else:            
            if(all( availability == 1 for (_, _, availability,_,_) in split_order(order).items)):
                Complete_orders.append(order)
                update_inv(order)
            else:
                Incomplete_orders.append(order)
                
    else:
        #West
        if(check_inv_west(order)):
            #print("All items for order",order.order_num," are avaible. All in West.")
            Complete_orders.append(order)
            update_inv(order)
        else:
            #Not all items are available in west inventory; setting all availibility to zero
            for item in order.items:
                item[2] = False
                #print("setting all availbility to zero.")
            if(check_inv_east(order)):
                #print("All items for order",order.order_num," are avaible. All in East.")
                Complete_orders.append(order)
                update_inv(order)
            else:            
                if(all( availability == 1 for (_, _, availability,_,_) in split_order(order).items)):
                    Complete_orders.append(order)
                    update_inv(order)
                else:
                    Incomplete_orders.append(order)
# Out:
# Not enough items in both inventory for item ['ZI-1505P', 2, False, 'unknown', ['””', '”2020/04/13 22:07:52”', '”2020/04/13”', '””', '””', '””', '””', '”フリーランス”', '””', '””', '””', '””', '””', '””', '”岡山県 倉敷市亀島1-32-5 プランタンブルックA201”', '””', '””', '””', '”S001417128”', '””', '””', '”フリーランス”', '”斎藤茉子”', '”佐川急便/千葉物流センタ01///BG”', '””', '”斎藤茉子”', '”様”', '”岡山県 倉敷市亀島1-32-5”', '”プランタンブルックA201”', '”09028699810”', '””', '””', '””', '””', '”sm.7785@i.softbank.jp”', '”62”', '””', '””', '””', '””', '””', '””', '””', '”/440”', '””', '””', '””', '””', '”4573191242932”', '””', '”カットウィッグBG211【メイク無しタイプ・人毛100%】”', '””', '””', '””', '”PC”', '””', '””', '””', '””', '””', '””', '”BG00”', '”なし”', '””', '””', '””']] in order 2001769876
# removing the parent order and replacing it with split order for order number: 2001772463 TT-0117P
# removing ['HC-4225N', 2, False, 'unknown', ['””', '”2020/04/14 22:59:57”', '”2020/04/14”', '””', '””', '””', '””', '”CLOVER”', '””', '””', '””', '””', '””', '””', '”広島県 福山市南蔵王町6-19-36”', '””', '””', '””', '”S001419047”', '””', '””', '”CLOVER”', '”松本\u3000康幸”', '”佐川急便/千葉物流センタ01///BG”', '””', '”松本\u3000康幸”', '”様”', '”広島県 福山市南蔵王町6-19-36”', '””', '”0849412548”', '””', '””', '””', '””', '”clover84@clear.ocn.ne.jp”', '”1937”', '””', '””', '””', '””', '””', '””', '””', '”/440”', '””', '””', '””', '””', '”4589743270094”', '””', '”【27009】リフュールカラー GR-6NB 120g≪グレイカラー≫【医薬部外”', '””', '””', '””', '”PC”', '””', '””', '””', '””', '””', '””', '”BG00”', '”なし”', '””', '””', '””']]
# removing the parent order and replacing it with split order for order number: 2001772492 HC-4229N
# removing the parent order and replacing it with split order for order number: 2001772163 WY-0090P
# Not enough items in both inventory for item ['TB-0150P', 2, False, 'unknown', ['””', '”2020/04/15 03:24:49”', '”2020/04/15”', '””', '””', '””', '””', '”day”', '””', '””', '””', '””', '””', '””', '”広島県 広島市西区三篠町2-5-7-2F”', '””', '””', '””', '”1000150141”', '””', '””', '”day”', '”day 中安”', '”佐川急便/千葉物流センタ01///EG”', '””', '”day 中安”', '”様”', '”広島県 広島市西区三篠町2-5-7-2F”', '””', '”0825558129”', '””', '””', '””', '””', '”yuka.nakaysu@gmail.com”', '”0”', '””', '””', '””', '””', '””', '””', '””', '”/800”', '””', '””', '””', '””', '”4571308041478”', '””', '”超吸水＆速乾マイクロファイバー特大タオルシーツ 110×220cm（ベージュ）”', '””', '””', '””', '”PC”', '””', '””', '””', '””', '””', '””', '”BG00”', '”なし”', '””', '””', '””']] in order 2001772707
# Not enough items in both inventory for item ['108538', 1, False, 'unknown', ['””', '”2020/04/15 03:24:49”', '”2020/04/15”', '””', '””', '””', '””', '”day”', '””', '””', '””', '””', '””', '””', '”広島県 広島市西区三篠町2-5-7-2F”', '””', '””', '””', '”1000150141”', '””', '””', '”day”', '”day 中安”', '”佐川急便/千葉物流センタ01///EG”', '””', '”day 中安”', '”様”', '”広島県 広島市西区三篠町2-5-7-2F”', '””', '”0825558129”', '””', '””', '””', '””', '”yuka.nakaysu@gmail.com”', '”0”', '””', '””', '””', '””', '””', '””', '””', '”/800”', '””', '””', '””', '””', '”4589747962803”', '””', '”【Rich Lash】肌にやさしいアイシート(100ペア)”', '””', '””', '””', '”PC”', '””', '””', '””', '””', '””', '””', '”BG00”', '”なし”', '””', '””', '””']] in order 2001772707
# removing the parent order and replacing it with split order for order number: 2001772550 118950
# Not enough items in both inventory for item ['112360', 1, False, 'unknown', ['””', '”2020/04/15 00:27:34”', '”2020/04/15”', '””', '””', '””', '””', '”トータルボディケアサロン\u3000Bean”', '””', '””', '””', '””', '””', '””', '”神奈川県 相模原市南区相模大野7-24-25 コスモヒルズ相模大野1002”', '””', '””', '””', '”S001419115”', '””', '””', '”トータルボディケアサロン\u3000Bean”', '”佐藤\u3000愛子”', '”佐川急便/千葉物流センタ01///BG”', '””', '”佐藤\u3000愛子”', '”様”', '”神奈川県 相模原市南区相模大野7-24-25”', '”コスモヒルズ相模大野1002”', '”0427478708”', '””', '””', '””', '””', '”beantoaiko@yahoo.co.jp”', '”1589”', '””', '””', '””', '””', '””', '””', '””', '”/312”', '””', '””', '””', '””', '”4573298916996”', '””', '”【miss eye d’or】フレッシュグループロフェッショナル150mPas”', '””', '””', '””', '”PC”', '””', '””', '””', '””', '””', '””', '”BG00”', '”なし”', '””', '””', '””']] in order 2001772649
# Not enough items in both inventory for item ['LO-2196P', 1, False, 'unknown', ['””', '”2020/04/15 00:27:34”', '”2020/04/15”', '””', '””', '””', '””', '”トータルボディケアサロン\u3000Bean”', '””', '””', '””', '””', '””', '””', '”神奈川県 相模原市南区相模大野7-24-25 コスモヒルズ相模大野1002”', '””', '””', '””', '”S001419115”', '””', '””', '”トータルボディケアサロン\u3000Bean”', '”佐藤\u3000愛子”', '”佐川急便/千葉物流センタ01///BG”', '””', '”佐藤\u3000愛子”', '”様”', '”神奈川県 相模原市南区相模大野7-24-25”', '”コスモヒルズ相模大野1002”', '”0427478708”', '””', '””', '””', '””', '”beantoaiko@yahoo.co.jp”', '”1589”', '””', '””', '””', '””', '””', '””', '””', '”/312”', '””', '””', '””', '””', '”4571308041539”', '””', '”アロマボディオイル【ラベンダー】1000ml”', '””', '””', '””', '”PC”', '””', '””', '””', '””', '””', '””', '”BG00”', '”なし”', '””', '””', '””']] in order 2001772649
# Not enough items in both inventory for item ['XT-2615P', 1, False, 'unknown', ['””', '”2020/04/15 07:55:57”', '”2020/04/15”', '””', '””', '””', '””', '”Aaty”', '””', '””', '””', '””', '””', '””', '”神奈川県 川崎市中原区宮内3-5-10-2”', '””', '””', '””', '”S001419204”', '””', '””', '”Aaty”', '””', '”佐川急便/千葉物流センタ01///BG”', '””', '”Aaty”', '”様”', '”神奈川県 川崎市中原区木月2-8-34”', '”内田ビル2F”', '”0444347757”', '””', '””', '””', '””', '”motoking.irie@gmail.com”', '”0”', '””', '””', '””', '””', '””', '””', '””', '”/312”', '””', '””', '””', '””', '”4573191243489”', '””', '”タオルウォーマーLサイズ（前開き）ダークブラウン”', '””', '””', '””', '”PC”', '””', '””', '””', '””', '””', '””', '”BG00”', '”1年”', '””', '””', '””']] in order 2001772745
# removing the parent order and replacing it with split order for order number: 2001772755 ZK-0078N
# removing the parent order and replacing it with split order for order number: 2001772755 ZY-0054N

# %% [raw]
# ---------------------------Output----------------------

# %%
Items_not_in_inv_east
# Out:
# []

# %%
len(List_of_index_orders) #number of orders
# Out:
# 18

# %%
len(Complete_orders) #number of orders that can be
# Out:
# 14

# %%
len(Incomplete_orders)
# Out:
# 4

# %%
len(df_order.index)
# Out:
# 54

# %%
lComplete_orders = list()
temp = list()
for order in Complete_orders:
    for i in range(len(order.items)):
        #order.order_num = '”' + order.order_num + '”'
        #order.zipcode = '”' + order.zipcode + '”'
        order.items[i][0] = '”' + order.items[i][0] + '”' #adds ” to code_name and numitemsneeded
        order.items[i][1] = '”' + str(order.items[i][1]) + '”'
        temp = [order.order_num, \
                order.items[i][4][0],order.items[i][4][1],order.items[i][4][2],order.items[i][4][3],\
                order.items[i][4][4],order.items[i][4][5],order.items[i][4][6],order.items[i][4][7],\
                order.items[i][4][8],order.items[i][4][9],order.items[i][4][10],order.items[i][4][11],\
                order.items[i][4][12],order.items[i][4][13],order.items[i][4][14],order.items[i][4][15],\
                order.items[i][4][16],order.items[i][4][17],order.items[i][4][18],order.items[i][4][19],\
                order.items[i][4][20],order.items[i][4][21],order.items[i][4][22],order.items[i][4][23],\
                order.items[i][4][24],order.items[i][4][25],order.items[i][4][26],order.zipcode,\
                order.items[i][4][27],order.items[i][4][28],order.items[i][4][29],order.items[i][4][30],\
                order.items[i][4][31],order.items[i][4][32],order.items[i][4][33],order.items[i][4][34],\
                order.items[i][4][35],order.items[i][4][36],order.items[i][4][37],order.items[i][4][38],\
                order.items[i][4][39],order.items[i][4][40],order.items[i][4][41],order.items[i][4][42],\
                order.items[i][4][43],order.items[i][4][44],order.items[i][4][45],order.items[i][4][46],\
                order.items[i][4][47],order.items[i][0],order.items[i][4][48],order.items[i][4][49],\
                order.items[i][4][50],order.items[i][4][51],order.items[i][4][52],order.items[i][4][53],\
                order.items[i][1],order.items[i][4][54],order.items[i][4][55],order.items[i][4][56],\
                order.items[i][4][57],order.items[i][4][58],order.items[i][4][59],order.items[i][4][60],\
                order.items[i][4][61],order.items[i][4][62],order.items[i][4][63],order.items[i][4][64],\
                order.items[i][4][65],order.items[i][2], order.items[i][3]]
        #print(list(itertools.chain(*temp)))
        lComplete_orders.append(temp)

# %%
lComplete_orders
# Out:
# [['2001771962',
#   '””',
#   '”2020/04/14 18:22:16”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”Sea\u3000gull.”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”広島県 山県郡北広島町春木９６０−６”',
#   '””',
#   '””',
#   '””',
#   '”S001418807”',
#   '””',
#   '””',
#   '”Sea\u3000gull.”',
#   '”平江\u3000三恵子”',
#   '”佐川急便/千葉物流センタ01/7378//BG”',
#   '””',
#   '”平江\u3000三恵子”',
#   '”様”',
#   '7311531',
#   '”広島県 山県郡北広島町春木960-7”',
#   '””',
#   '”0826720324”',
#   '””',
#   '”666”',
#   '””',
#   '””',
#   '”hirae1031@hi.enjoy.ne.jp”',
#   '”756”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/440”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”HD-3113N”',
#   '”4954835334815”',
#   '””',
#   '”オルディーブ アディクシー オキシダン 6% 1000ml【医薬部外品】”',
#   '””',
#   '””',
#   '””',
#   '”1”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'West'],
#  ['2001771962',
#   '””',
#   '”2020/04/14 18:22:16”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”Sea\u3000gull.”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”広島県 山県郡北広島町春木９６０−６”',
#   '””',
#   '””',
#   '””',
#   '”S001418807”',
#   '””',
#   '””',
#   '”Sea\u3000gull.”',
#   '”平江\u3000三恵子”',
#   '”佐川急便/千葉物流センタ01/7378//BG”',
#   '””',
#   '”平江\u3000三恵子”',
#   '”様”',
#   '7311531',
#   '”広島県 山県郡北広島町春木960-7”',
#   '””',
#   '”0826720324”',
#   '””',
#   '”666”',
#   '””',
#   '””',
#   '”hirae1031@hi.enjoy.ne.jp”',
#   '”756”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/440”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”HC-4561N”',
#   '”4954835334525”',
#   '””',
#   '”オルディーブ アディクシー サファイア9 80g【医薬部外品】”',
#   '””',
#   '””',
#   '””',
#   '”1”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'West'],
#  ['2001771962',
#   '””',
#   '”2020/04/14 18:22:16”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”Sea\u3000gull.”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”広島県 山県郡北広島町春木９６０−６”',
#   '””',
#   '””',
#   '””',
#   '”S001418807”',
#   '””',
#   '””',
#   '”Sea\u3000gull.”',
#   '”平江\u3000三恵子”',
#   '”佐川急便/千葉物流センタ01/7378//BG”',
#   '””',
#   '”平江\u3000三恵子”',
#   '”様”',
#   '7311531',
#   '”広島県 山県郡北広島町春木960-7”',
#   '””',
#   '”0826720324”',
#   '””',
#   '”666”',
#   '””',
#   '””',
#   '”hirae1031@hi.enjoy.ne.jp”',
#   '”756”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/440”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”HC-4560N”',
#   '”4954835334518”',
#   '””',
#   '”オルディーブ アディクシー サファイア13 80g【医薬部外品】”',
#   '””',
#   '””',
#   '””',
#   '”1”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'West'],
#  ['2001771962',
#   '””',
#   '”2020/04/14 18:22:16”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”Sea\u3000gull.”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”広島県 山県郡北広島町春木９６０−６”',
#   '””',
#   '””',
#   '””',
#   '”S001418807”',
#   '””',
#   '””',
#   '”Sea\u3000gull.”',
#   '”平江\u3000三恵子”',
#   '”佐川急便/千葉物流センタ01/7378//BG”',
#   '””',
#   '”平江\u3000三恵子”',
#   '”様”',
#   '7311531',
#   '”広島県 山県郡北広島町春木960-7”',
#   '””',
#   '”0826720324”',
#   '””',
#   '”666”',
#   '””',
#   '””',
#   '”hirae1031@hi.enjoy.ne.jp”',
#   '”756”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/440”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”HD-0079P”',
#   '”4560441262956”',
#   '””',
#   '”sroloc OX6% (エスロロック 2剤) 2000ml【医薬部外品】”',
#   '””',
#   '””',
#   '””',
#   '”1”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'West'],
#  ['2001771962',
#   '””',
#   '”2020/04/14 18:22:16”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”Sea\u3000gull.”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”広島県 山県郡北広島町春木９６０−６”',
#   '””',
#   '””',
#   '””',
#   '”S001418807”',
#   '””',
#   '””',
#   '”Sea\u3000gull.”',
#   '”平江\u3000三恵子”',
#   '”佐川急便/千葉物流センタ01/7378//BG”',
#   '””',
#   '”平江\u3000三恵子”',
#   '”様”',
#   '7311531',
#   '”広島県 山県郡北広島町春木960-7”',
#   '””',
#   '”0826720324”',
#   '””',
#   '”666”',
#   '””',
#   '””',
#   '”hirae1031@hi.enjoy.ne.jp”',
#   '”756”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/440”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”HC-3214P”',
#   '”4573191231028”',
#   '””',
#   '”sroloc N-7D (エスロロック ナチュラル7ディープブラージュ) 120”',
#   '””',
#   '””',
#   '””',
#   '”2”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'West'],
#  ['2001771962',
#   '””',
#   '”2020/04/14 18:22:16”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”Sea\u3000gull.”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”広島県 山県郡北広島町春木９６０−６”',
#   '””',
#   '””',
#   '””',
#   '”S001418807”',
#   '””',
#   '””',
#   '”Sea\u3000gull.”',
#   '”平江\u3000三恵子”',
#   '”佐川急便/千葉物流センタ01/7378//BG”',
#   '””',
#   '”平江\u3000三恵子”',
#   '”様”',
#   '7311531',
#   '”広島県 山県郡北広島町春木960-7”',
#   '””',
#   '”0826720324”',
#   '””',
#   '”666”',
#   '””',
#   '””',
#   '”hirae1031@hi.enjoy.ne.jp”',
#   '”756”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/440”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”HC-3215P”',
#   '”4573191231011”',
#   '””',
#   '”sroloc N-9D (エスロロック ナチュラル9ディープブラージュ) 120”',
#   '””',
#   '””',
#   '””',
#   '”2”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'West'],
#  ['2001771962',
#   '””',
#   '”2020/04/14 18:22:16”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”Sea\u3000gull.”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”広島県 山県郡北広島町春木９６０−６”',
#   '””',
#   '””',
#   '””',
#   '”S001418807”',
#   '””',
#   '””',
#   '”Sea\u3000gull.”',
#   '”平江\u3000三恵子”',
#   '”佐川急便/千葉物流センタ01/7378//BG”',
#   '””',
#   '”平江\u3000三恵子”',
#   '”様”',
#   '7311531',
#   '”広島県 山県郡北広島町春木960-7”',
#   '””',
#   '”0826720324”',
#   '””',
#   '”666”',
#   '””',
#   '””',
#   '”hirae1031@hi.enjoy.ne.jp”',
#   '”756”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/440”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”TZ-0410P”',
#   '”4560441266176”',
#   '””',
#   '”Baby Touch フェイシャルコットン Mサイズ（60×80mm/500枚入”',
#   '””',
#   '””',
#   '””',
#   '”1”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'West'],
#  ['2001771962',
#   '””',
#   '”2020/04/14 18:22:16”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”Sea\u3000gull.”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”広島県 山県郡北広島町春木９６０−６”',
#   '””',
#   '””',
#   '””',
#   '”S001418807”',
#   '””',
#   '””',
#   '”Sea\u3000gull.”',
#   '”平江\u3000三恵子”',
#   '”佐川急便/千葉物流センタ01/7378//BG”',
#   '””',
#   '”平江\u3000三恵子”',
#   '”様”',
#   '7311531',
#   '”広島県 山県郡北広島町春木960-7”',
#   '””',
#   '”0826720324”',
#   '””',
#   '”666”',
#   '””',
#   '””',
#   '”hirae1031@hi.enjoy.ne.jp”',
#   '”756”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/440”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”HC-4570N”',
#   '”4954835334617”',
#   '””',
#   '”オルディーブ アディクシー エメラルド13 80g【医薬部外品】”',
#   '””',
#   '””',
#   '””',
#   '”1”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'West'],
#  ['2001771962',
#   '””',
#   '”2020/04/14 18:22:16”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”Sea\u3000gull.”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”広島県 山県郡北広島町春木９６０−６”',
#   '””',
#   '””',
#   '””',
#   '”S001418807”',
#   '””',
#   '””',
#   '”Sea\u3000gull.”',
#   '”平江\u3000三恵子”',
#   '”佐川急便/千葉物流センタ01/7378//BG”',
#   '””',
#   '”平江\u3000三恵子”',
#   '”様”',
#   '7311531',
#   '”広島県 山県郡北広島町春木960-7”',
#   '””',
#   '”0826720324”',
#   '””',
#   '”666”',
#   '””',
#   '””',
#   '”hirae1031@hi.enjoy.ne.jp”',
#   '”756”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/440”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”HC-3216P”',
#   '”4573191231035”',
#   '””',
#   '”sroloc N-6D (エスロロック ナチュラル6ディープブラージュ) 120”',
#   '””',
#   '””',
#   '””',
#   '”2”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'West'],
#  ['2001771984',
#   '””',
#   '”2020/04/14 18:49:11”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”シャルム”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”広島県 広島市西区井口鈴が台３−１３−３４”',
#   '””',
#   '””',
#   '””',
#   '”S001418827”',
#   '””',
#   '””',
#   '”シャルム”',
#   '”池上愛美”',
#   '”佐川急便/千葉物流センタ01///BG”',
#   '””',
#   '”池上愛美”',
#   '”様”',
#   '7330843',
#   '”広島県 広島市西区井口鈴が台３−１３−３４”',
#   '””',
#   '”08063308287”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”anmi02151221@gmail.com”',
#   '”743”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/440”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”LX-0256P”',
#   '”6950169420246”',
#   '””',
#   '”フレーバーワックス 脱毛用ハードワックス ブラジル400ml”',
#   '””',
#   '””',
#   '””',
#   '”2”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'East'],
#  ['2001771984',
#   '””',
#   '”2020/04/14 18:49:11”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”シャルム”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”広島県 広島市西区井口鈴が台３−１３−３４”',
#   '””',
#   '””',
#   '””',
#   '”S001418827”',
#   '””',
#   '””',
#   '”シャルム”',
#   '”池上愛美”',
#   '”佐川急便/千葉物流センタ01///BG”',
#   '””',
#   '”池上愛美”',
#   '”様”',
#   '7330843',
#   '”広島県 広島市西区井口鈴が台３−１３−３４”',
#   '””',
#   '”08063308287”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”anmi02151221@gmail.com”',
#   '”743”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/440”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”LX-0257P”',
#   '”6950169420222”',
#   '””',
#   '”フレーバーワックス 脱毛用ハードワックス ローズ400ml”',
#   '””',
#   '””',
#   '””',
#   '”2”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'East'],
#  ['2001771999',
#   '””',
#   '”2020/04/14 19:01:14”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”ボディケア\u3000縁-えにし-”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”広島県 広島市安佐南区西原5丁目１７番２７号”',
#   '””',
#   '””',
#   '””',
#   '”S001418843”',
#   '””',
#   '””',
#   '”ボディケア\u3000縁-えにし-”',
#   '”今村孝美”',
#   '”佐川急便/千葉物流センタ01/5000/01/BG”',
#   '””',
#   '”今村孝美”',
#   '”様”',
#   '7310113',
#   '”広島県 広島市安佐南区西原5丁目１７番２７号”',
#   '””',
#   '”09048061031”',
#   '””',
#   '”455”',
#   '””',
#   '””',
#   '”ta-1101-ka@leaf.ocn.ne.jp”',
#   '”190”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/440”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”LO-2612P”',
#   '”4571308041560”',
#   '””',
#   '”シアバターマッサージクリーム450g【業務用】”',
#   '””',
#   '””',
#   '””',
#   '”5”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'West'],
#  ['2001772059',
#   '””',
#   '”2020/04/14 19:57:02”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”庄司 悦子”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”広島県 福山市北吉津町3-7 3-333”',
#   '””',
#   '””',
#   '””',
#   '”S001418894”',
#   '””',
#   '””',
#   '”庄司 悦子”',
#   '””',
#   '”佐川急便/千葉物流センタ01/7741//BG”',
#   '””',
#   '”庄司 悦子”',
#   '”様”',
#   '7200073',
#   '”広島県 福山市北吉津町3-7”',
#   '”3-333”',
#   '”09064041404”',
#   '””',
#   '”703”',
#   '””',
#   '””',
#   '”masa-respect-lv@i.softbank.jp”',
#   '”557”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/440”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”ER-0087P”',
#   '”4573191230373”',
#   '””',
#   '”業務用ソニックスキンクリーナーMA-003”',
#   '””',
#   '””',
#   '””',
#   '”1”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”1年”',
#   '””',
#   '””',
#   '””',
#   True,
#   'East'],
#  ['2001772463',
#   '””',
#   '”2020/04/14 22:48:37”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”悠心堂”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”広島県 呉市川尻町原山1-6-19”',
#   '””',
#   '””',
#   '””',
#   '”S001419042”',
#   '””',
#   '””',
#   '”悠心堂”',
#   '”久保田悠”',
#   '”佐川急便/千葉物流センタ01///BG”',
#   '””',
#   '”久保田悠”',
#   '”様”',
#   '7372601',
#   '”広島県 呉市川尻町原山1-6-19”',
#   '””',
#   '”08062408917”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”kbtac09@gmail.com”',
#   '”196”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/440”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”TT-0117P”',
#   '”4573191243977”',
#   '””',
#   '”使い捨てベッドシーツ SP 90M（ホワイト）”',
#   '””',
#   '””',
#   '””',
#   '”1”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'East'],
#  ['2001772463',
#   '””',
#   '”2020/04/14 22:48:37”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”悠心堂”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”広島県 呉市川尻町原山1-6-19”',
#   '””',
#   '””',
#   '””',
#   '”S001419042”',
#   '””',
#   '””',
#   '”悠心堂”',
#   '”久保田悠”',
#   '”佐川急便/千葉物流センタ01///BG”',
#   '””',
#   '”久保田悠”',
#   '”様”',
#   '7372601',
#   '”広島県 呉市川尻町原山1-6-19”',
#   '””',
#   '”08062408917”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”kbtac09@gmail.com”',
#   '”196”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/440”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”TT-0117P”',
#   '”4573191243977”',
#   '””',
#   '”使い捨てベッドシーツ SP 90M（ホワイト）”',
#   '””',
#   '””',
#   '””',
#   '”3”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'West'],
#  ['2001772492',
#   '””',
#   '”2020/04/14 22:59:57”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”CLOVER”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”広島県 福山市南蔵王町6-19-36”',
#   '””',
#   '””',
#   '””',
#   '”S001419047”',
#   '””',
#   '””',
#   '”CLOVER”',
#   '”松本\u3000康幸”',
#   '”佐川急便/千葉物流センタ01///BG”',
#   '””',
#   '”松本\u3000康幸”',
#   '”様”',
#   '7210973',
#   '”広島県 福山市南蔵王町6-19-36”',
#   '””',
#   '”0849412548”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”clover84@clear.ocn.ne.jp”',
#   '”1937”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/440”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”HC-4225N”',
#   '”4589743270094”',
#   '””',
#   '”【27009】リフュールカラー GR-6NB 120g≪グレイカラー≫【医薬部外”',
#   '””',
#   '””',
#   '””',
#   '”4”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'East'],
#  ['2001772492',
#   '””',
#   '”2020/04/14 22:59:57”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”CLOVER”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”広島県 福山市南蔵王町6-19-36”',
#   '””',
#   '””',
#   '””',
#   '”S001419047”',
#   '””',
#   '””',
#   '”CLOVER”',
#   '”松本\u3000康幸”',
#   '”佐川急便/千葉物流センタ01///BG”',
#   '””',
#   '”松本\u3000康幸”',
#   '”様”',
#   '7210973',
#   '”広島県 福山市南蔵王町6-19-36”',
#   '””',
#   '”0849412548”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”clover84@clear.ocn.ne.jp”',
#   '”1937”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/440”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”HC-4224N”',
#   '”4589743270100”',
#   '””',
#   '”【27010】リフュールカラー GR-7NB 120g≪グレイカラー≫【医薬部外”',
#   '””',
#   '””',
#   '””',
#   '”5”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'East'],
#  ['2001772492',
#   '””',
#   '”2020/04/14 22:59:57”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”CLOVER”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”広島県 福山市南蔵王町6-19-36”',
#   '””',
#   '””',
#   '””',
#   '”S001419047”',
#   '””',
#   '””',
#   '”CLOVER”',
#   '”松本\u3000康幸”',
#   '”佐川急便/千葉物流センタ01///BG”',
#   '””',
#   '”松本\u3000康幸”',
#   '”様”',
#   '7210973',
#   '”広島県 福山市南蔵王町6-19-36”',
#   '””',
#   '”0849412548”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”clover84@clear.ocn.ne.jp”',
#   '”1937”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/440”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”HC-4223N”',
#   '”4589743270117”',
#   '””',
#   '”【27011】リフュールカラー GR-8NB 120g≪グレイカラー≫【医薬部外”',
#   '””',
#   '””',
#   '””',
#   '”1”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'East'],
#  ['2001772492',
#   '””',
#   '”2020/04/14 22:59:57”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”CLOVER”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”広島県 福山市南蔵王町6-19-36”',
#   '””',
#   '””',
#   '””',
#   '”S001419047”',
#   '””',
#   '””',
#   '”CLOVER”',
#   '”松本\u3000康幸”',
#   '”佐川急便/千葉物流センタ01///BG”',
#   '””',
#   '”松本\u3000康幸”',
#   '”様”',
#   '7210973',
#   '”広島県 福山市南蔵王町6-19-36”',
#   '””',
#   '”0849412548”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”clover84@clear.ocn.ne.jp”',
#   '”1937”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/440”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”HC-4222N”',
#   '”4589743270124”',
#   '””',
#   '”【27012】リフュールカラー GR-9NB 120g≪グレイカラー≫【医薬部外”',
#   '””',
#   '””',
#   '””',
#   '”2”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'East'],
#  ['2001772492',
#   '””',
#   '”2020/04/14 22:59:57”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”CLOVER”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”広島県 福山市南蔵王町6-19-36”',
#   '””',
#   '””',
#   '””',
#   '”S001419047”',
#   '””',
#   '””',
#   '”CLOVER”',
#   '”松本\u3000康幸”',
#   '”佐川急便/千葉物流センタ01///BG”',
#   '””',
#   '”松本\u3000康幸”',
#   '”様”',
#   '7210973',
#   '”広島県 福山市南蔵王町6-19-36”',
#   '””',
#   '”0849412548”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”clover84@clear.ocn.ne.jp”',
#   '”1937”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/440”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”HC-4211N”',
#   '”4589743270230”',
#   '””',
#   '”【27023】リフュールカラー GR-7AB 120g≪グレイカラー≫【医薬部外”',
#   '””',
#   '””',
#   '””',
#   '”1”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'West'],
#  ['2001772492',
#   '””',
#   '”2020/04/14 22:59:57”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”CLOVER”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”広島県 福山市南蔵王町6-19-36”',
#   '””',
#   '””',
#   '””',
#   '”S001419047”',
#   '””',
#   '””',
#   '”CLOVER”',
#   '”松本\u3000康幸”',
#   '”佐川急便/千葉物流センタ01///BG”',
#   '””',
#   '”松本\u3000康幸”',
#   '”様”',
#   '7210973',
#   '”広島県 福山市南蔵王町6-19-36”',
#   '””',
#   '”0849412548”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”clover84@clear.ocn.ne.jp”',
#   '”1937”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/440”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”HC-4201N”',
#   '”4589743270339”',
#   '””',
#   '”【27033】リフュールカラー GR-6RB 120g≪グレイカラー≫【医薬部外”',
#   '””',
#   '””',
#   '””',
#   '”2”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'East'],
#  ['2001772492',
#   '””',
#   '”2020/04/14 22:59:57”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”CLOVER”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”広島県 福山市南蔵王町6-19-36”',
#   '””',
#   '””',
#   '””',
#   '”S001419047”',
#   '””',
#   '””',
#   '”CLOVER”',
#   '”松本\u3000康幸”',
#   '”佐川急便/千葉物流センタ01///BG”',
#   '””',
#   '”松本\u3000康幸”',
#   '”様”',
#   '7210973',
#   '”広島県 福山市南蔵王町6-19-36”',
#   '””',
#   '”0849412548”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”clover84@clear.ocn.ne.jp”',
#   '”1937”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/440”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”HD-0079P”',
#   '”4560441262956”',
#   '””',
#   '”sroloc OX6% (エスロロック 2剤) 2000ml【医薬部外品】”',
#   '””',
#   '””',
#   '””',
#   '”1”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'East'],
#  ['2001772492',
#   '””',
#   '”2020/04/14 22:59:57”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”CLOVER”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”広島県 福山市南蔵王町6-19-36”',
#   '””',
#   '””',
#   '””',
#   '”S001419047”',
#   '””',
#   '””',
#   '”CLOVER”',
#   '”松本\u3000康幸”',
#   '”佐川急便/千葉物流センタ01///BG”',
#   '””',
#   '”松本\u3000康幸”',
#   '”様”',
#   '7210973',
#   '”広島県 福山市南蔵王町6-19-36”',
#   '””',
#   '”0849412548”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”clover84@clear.ocn.ne.jp”',
#   '”1937”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/440”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”HT-0458N”',
#   '”4961503534385”',
#   '””',
#   '”【53438】ディープレイヤー5(パウチ）800g”',
#   '””',
#   '””',
#   '””',
#   '”1”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'East'],
#  ['2001772492',
#   '””',
#   '”2020/04/14 22:59:57”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”CLOVER”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”広島県 福山市南蔵王町6-19-36”',
#   '””',
#   '””',
#   '””',
#   '”S001419047”',
#   '””',
#   '””',
#   '”CLOVER”',
#   '”松本\u3000康幸”',
#   '”佐川急便/千葉物流センタ01///BG”',
#   '””',
#   '”松本\u3000康幸”',
#   '”様”',
#   '7210973',
#   '”広島県 福山市南蔵王町6-19-36”',
#   '””',
#   '”0849412548”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”clover84@clear.ocn.ne.jp”',
#   '”1937”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/440”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”HC-4317N”',
#   '”4589743270087”',
#   '””',
#   '”【27008】リフュールカラー GR-5NB 120g≪グレイカラー≫【医薬部外”',
#   '””',
#   '””',
#   '””',
#   '”2”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'East'],
#  ['2001772492',
#   '””',
#   '”2020/04/14 22:59:57”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”CLOVER”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”広島県 福山市南蔵王町6-19-36”',
#   '””',
#   '””',
#   '””',
#   '”S001419047”',
#   '””',
#   '””',
#   '”CLOVER”',
#   '”松本\u3000康幸”',
#   '”佐川急便/千葉物流センタ01///BG”',
#   '””',
#   '”松本\u3000康幸”',
#   '”様”',
#   '7210973',
#   '”広島県 福山市南蔵王町6-19-36”',
#   '””',
#   '”0849412548”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”clover84@clear.ocn.ne.jp”',
#   '”1937”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/440”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”HC-4229N”',
#   '”4589743270063”',
#   '””',
#   '”【27006】リフュールカラー GR-3NB 120g≪グレイカラー≫【医薬部外”',
#   '””',
#   '””',
#   '””',
#   '”1”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'East'],
#  ['2001772492',
#   '””',
#   '”2020/04/14 22:59:57”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”CLOVER”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”広島県 福山市南蔵王町6-19-36”',
#   '””',
#   '””',
#   '””',
#   '”S001419047”',
#   '””',
#   '””',
#   '”CLOVER”',
#   '”松本\u3000康幸”',
#   '”佐川急便/千葉物流センタ01///BG”',
#   '””',
#   '”松本\u3000康幸”',
#   '”様”',
#   '7210973',
#   '”広島県 福山市南蔵王町6-19-36”',
#   '””',
#   '”0849412548”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”clover84@clear.ocn.ne.jp”',
#   '”1937”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/440”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”HC-4229N”',
#   '”4589743270063”',
#   '””',
#   '”【27006】リフュールカラー GR-3NB 120g≪グレイカラー≫【医薬部外”',
#   '””',
#   '””',
#   '””',
#   '”2”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'West'],
#  ['2001772004',
#   '””',
#   '”2020/04/14 19:09:44”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”阪本恵美”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”神奈川県 大和市西鶴間3-11-26 フォレスト鶴間101”',
#   '””',
#   '””',
#   '””',
#   '”S001418848”',
#   '””',
#   '””',
#   '”阪本恵美”',
#   '””',
#   '”佐川急便/千葉物流センタ01//04/BG”',
#   '””',
#   '”阪本恵美”',
#   '”様”',
#   '2420005',
#   '”神奈川県 大和市西鶴間3-11-26”',
#   '”フォレスト鶴間101”',
#   '”08068082221”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”20071111@ezweb.ne.jp”',
#   '”1363”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/312”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”LN-2867N”',
#   '”4582214320847”',
#   '””',
#   '”ジョリ セラミドクリーム 500g【業務用】”',
#   '””',
#   '””',
#   '””',
#   '”3”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'East'],
#  ['2001772004',
#   '””',
#   '”2020/04/14 19:09:44”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”阪本恵美”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”神奈川県 大和市西鶴間3-11-26 フォレスト鶴間101”',
#   '””',
#   '””',
#   '””',
#   '”S001418848”',
#   '””',
#   '””',
#   '”阪本恵美”',
#   '””',
#   '”佐川急便/千葉物流センタ01//04/BG”',
#   '””',
#   '”阪本恵美”',
#   '”様”',
#   '2420005',
#   '”神奈川県 大和市西鶴間3-11-26”',
#   '”フォレスト鶴間101”',
#   '”08068082221”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”20071111@ezweb.ne.jp”',
#   '”1363”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/312”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”TC-0147P”',
#   '”4560441267524”',
#   '””',
#   '”ECOペーパーショーツ【フリー】50枚(ダークブラウン)”',
#   '””',
#   '””',
#   '””',
#   '”1”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'East'],
#  ['2001772004',
#   '””',
#   '”2020/04/14 19:09:44”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”阪本恵美”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”神奈川県 大和市西鶴間3-11-26 フォレスト鶴間101”',
#   '””',
#   '””',
#   '””',
#   '”S001418848”',
#   '””',
#   '””',
#   '”阪本恵美”',
#   '””',
#   '”佐川急便/千葉物流センタ01//04/BG”',
#   '””',
#   '”阪本恵美”',
#   '”様”',
#   '2420005',
#   '”神奈川県 大和市西鶴間3-11-26”',
#   '”フォレスト鶴間101”',
#   '”08068082221”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”20071111@ezweb.ne.jp”',
#   '”1363”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/312”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”TC-0182P”',
#   '”4571308047678”',
#   '””',
#   '”ECOペーパーショーツ【3L】50枚(ダークブラウン)”',
#   '””',
#   '””',
#   '””',
#   '”1”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'East'],
#  ['2001772007',
#   '””',
#   '”2020/04/14 19:12:33”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”I&B\u3000NaFaS”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”神奈川県 小田原市蓮正寺239-2-103”',
#   '””',
#   '””',
#   '””',
#   '”S001418851”',
#   '””',
#   '””',
#   '”I&B\u3000NaFaS”',
#   '”小山加代子”',
#   '”佐川急便/千葉物流センタ01/3361//BG”',
#   '””',
#   '”小山加代子”',
#   '”様”',
#   '2590853',
#   '”神奈川県 小田原市蓮正寺239-2-103”',
#   '””',
#   '”09053436460”',
#   '””',
#   '”305”',
#   '””',
#   '””',
#   '”fifty51onekk@gmail.com”',
#   '”209”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/312”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”LE-0184N”',
#   '”4949658056242”',
#   '””',
#   '”オーガニック エッセンシャルオイル ティートリー5ml”',
#   '””',
#   '””',
#   '””',
#   '”1”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'West'],
#  ['2001772007',
#   '””',
#   '”2020/04/14 19:12:33”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”I&B\u3000NaFaS”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”神奈川県 小田原市蓮正寺239-2-103”',
#   '””',
#   '””',
#   '””',
#   '”S001418851”',
#   '””',
#   '””',
#   '”I&B\u3000NaFaS”',
#   '”小山加代子”',
#   '”佐川急便/千葉物流センタ01/3361//BG”',
#   '””',
#   '”小山加代子”',
#   '”様”',
#   '2590853',
#   '”神奈川県 小田原市蓮正寺239-2-103”',
#   '””',
#   '”09053436460”',
#   '””',
#   '”305”',
#   '””',
#   '””',
#   '”fifty51onekk@gmail.com”',
#   '”209”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/312”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”LW-2398P”',
#   '”4573191244691”',
#   '””',
#   '”Koh To Ka（コートーカ）エッセンスローション 200ml【店販用】”',
#   '””',
#   '””',
#   '””',
#   '”1”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'West'],
#  ['2001772085',
#   '””',
#   '”2020/04/14 20:19:48”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”小林ひろみ”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”神奈川県 茅ヶ崎市東海岸南6-4-37-B-308”',
#   '””',
#   '””',
#   '””',
#   '”1000150115”',
#   '””',
#   '””',
#   '”小林ひろみ”',
#   '””',
#   '”佐川急便/千葉物流センタ01///EG”',
#   '””',
#   '”小林ひろみ”',
#   '”様”',
#   '2530054',
#   '”神奈川県 茅ヶ崎市東海岸南6-4-37-B-308”',
#   '””',
#   '”09025277343”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”be_thankful_for_beauty@yahoo.co.jp”',
#   '”0”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/800”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”112870”',
#   '”4589985554686”',
#   '””',
#   '”【LADYCOCO】Lash Glue No1 5ml”',
#   '””',
#   '””',
#   '””',
#   '”1”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'East'],
#  ['2001772163',
#   '””',
#   '”2020/04/14 21:29:28”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”宮島つくみ”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”東京都 国立市富士見台1-10-48 小川ビル1F”',
#   '””',
#   '””',
#   '””',
#   '”S001418987”',
#   '””',
#   '””',
#   '”宮島つくみ”',
#   '””',
#   '”佐川急便/千葉物流センタ01///BG”',
#   '””',
#   '”宮島つくみ”',
#   '”様”',
#   '2110053',
#   '”神奈川県 川崎市中原区上小田中6-23-28”',
#   '”ミニョンヴィラージュ211”',
#   '”08033902934”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”tsukunail0224@gmail.com”',
#   '”3079”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/312”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”108814”',
#   '”4573298912943”',
#   '””',
#   '”プラチナセーブル[Cカール太さ0.05長さ10mm]”',
#   '””',
#   '””',
#   '””',
#   '”1”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'East'],
#  ['2001772163',
#   '””',
#   '”2020/04/14 21:29:28”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”宮島つくみ”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”東京都 国立市富士見台1-10-48 小川ビル1F”',
#   '””',
#   '””',
#   '””',
#   '”S001418987”',
#   '””',
#   '””',
#   '”宮島つくみ”',
#   '””',
#   '”佐川急便/千葉物流センタ01///BG”',
#   '””',
#   '”宮島つくみ”',
#   '”様”',
#   '2110053',
#   '”神奈川県 川崎市中原区上小田中6-23-28”',
#   '”ミニョンヴィラージュ211”',
#   '”08033902934”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”tsukunail0224@gmail.com”',
#   '”3079”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/312”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”WY-0069P”',
#   '”4589747961080”',
#   '””',
#   '”【RichiLash】クイックボリューム3本束 Cカール[太さ0.05 長さ10”',
#   '””',
#   '””',
#   '””',
#   '”1”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'West'],
#  ['2001772163',
#   '””',
#   '”2020/04/14 21:29:28”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”宮島つくみ”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”東京都 国立市富士見台1-10-48 小川ビル1F”',
#   '””',
#   '””',
#   '””',
#   '”S001418987”',
#   '””',
#   '””',
#   '”宮島つくみ”',
#   '””',
#   '”佐川急便/千葉物流センタ01///BG”',
#   '””',
#   '”宮島つくみ”',
#   '”様”',
#   '2110053',
#   '”神奈川県 川崎市中原区上小田中6-23-28”',
#   '”ミニョンヴィラージュ211”',
#   '”08033902934”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”tsukunail0224@gmail.com”',
#   '”3079”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/312”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”WY-0091P”',
#   '”4589747961301”',
#   '””',
#   '”【RichiLash】クイックボリューム3本束 Cカール[太さ0.07 長さ11”',
#   '””',
#   '””',
#   '””',
#   '”1”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'West'],
#  ['2001772163',
#   '””',
#   '”2020/04/14 21:29:28”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”宮島つくみ”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”東京都 国立市富士見台1-10-48 小川ビル1F”',
#   '””',
#   '””',
#   '””',
#   '”S001418987”',
#   '””',
#   '””',
#   '”宮島つくみ”',
#   '””',
#   '”佐川急便/千葉物流センタ01///BG”',
#   '””',
#   '”宮島つくみ”',
#   '”様”',
#   '2110053',
#   '”神奈川県 川崎市中原区上小田中6-23-28”',
#   '”ミニョンヴィラージュ211”',
#   '”08033902934”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”tsukunail0224@gmail.com”',
#   '”3079”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/312”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”WY-0076P”',
#   '”4589747961158”',
#   '””',
#   '”【RichiLash】クイックボリューム4本束 Cカール[太さ0.05 長さ10”',
#   '””',
#   '””',
#   '””',
#   '”2”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'East'],
#  ['2001772163',
#   '””',
#   '”2020/04/14 21:29:28”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”宮島つくみ”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”東京都 国立市富士見台1-10-48 小川ビル1F”',
#   '””',
#   '””',
#   '””',
#   '”S001418987”',
#   '””',
#   '””',
#   '”宮島つくみ”',
#   '””',
#   '”佐川急便/千葉物流センタ01///BG”',
#   '””',
#   '”宮島つくみ”',
#   '”様”',
#   '2110053',
#   '”神奈川県 川崎市中原区上小田中6-23-28”',
#   '”ミニョンヴィラージュ211”',
#   '”08033902934”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”tsukunail0224@gmail.com”',
#   '”3079”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/312”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”WY-0078P”',
#   '”4589747961172”',
#   '””',
#   '”【RichiLash】クイックボリューム4本束 Cカール[太さ0.05 長さ12”',
#   '””',
#   '””',
#   '””',
#   '”1”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'East'],
#  ['2001772163',
#   '””',
#   '”2020/04/14 21:29:28”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”宮島つくみ”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”東京都 国立市富士見台1-10-48 小川ビル1F”',
#   '””',
#   '””',
#   '””',
#   '”S001418987”',
#   '””',
#   '””',
#   '”宮島つくみ”',
#   '””',
#   '”佐川急便/千葉物流センタ01///BG”',
#   '””',
#   '”宮島つくみ”',
#   '”様”',
#   '2110053',
#   '”神奈川県 川崎市中原区上小田中6-23-28”',
#   '”ミニョンヴィラージュ211”',
#   '”08033902934”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”tsukunail0224@gmail.com”',
#   '”3079”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/312”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”WY-0083P”',
#   '”4589747961226”',
#   '””',
#   '”【RichiLash】クイックボリューム5本束 Cカール[太さ0.05 長さ10”',
#   '””',
#   '””',
#   '””',
#   '”1”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'East'],
#  ['2001772163',
#   '””',
#   '”2020/04/14 21:29:28”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”宮島つくみ”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”東京都 国立市富士見台1-10-48 小川ビル1F”',
#   '””',
#   '””',
#   '””',
#   '”S001418987”',
#   '””',
#   '””',
#   '”宮島つくみ”',
#   '””',
#   '”佐川急便/千葉物流センタ01///BG”',
#   '””',
#   '”宮島つくみ”',
#   '”様”',
#   '2110053',
#   '”神奈川県 川崎市中原区上小田中6-23-28”',
#   '”ミニョンヴィラージュ211”',
#   '”08033902934”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”tsukunail0224@gmail.com”',
#   '”3079”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/312”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”WY-0090P”',
#   '”4589747961295”',
#   '””',
#   '”【RichiLash】クイックボリューム3本束 Cカール[太さ0.07 長さ10”',
#   '””',
#   '””',
#   '””',
#   '”1”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'East'],
#  ['2001772163',
#   '””',
#   '”2020/04/14 21:29:28”',
#   '”2020/04/14”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”宮島つくみ”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”東京都 国立市富士見台1-10-48 小川ビル1F”',
#   '””',
#   '””',
#   '””',
#   '”S001418987”',
#   '””',
#   '””',
#   '”宮島つくみ”',
#   '””',
#   '”佐川急便/千葉物流センタ01///BG”',
#   '””',
#   '”宮島つくみ”',
#   '”様”',
#   '2110053',
#   '”神奈川県 川崎市中原区上小田中6-23-28”',
#   '”ミニョンヴィラージュ211”',
#   '”08033902934”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”tsukunail0224@gmail.com”',
#   '”3079”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/312”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”WY-0090P”',
#   '”4589747961295”',
#   '””',
#   '”【RichiLash】クイックボリューム3本束 Cカール[太さ0.07 長さ10”',
#   '””',
#   '””',
#   '””',
#   '”1”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'West'],
#  ['2001772740',
#   '””',
#   '”2020/04/15 07:51:26”',
#   '”2020/04/15”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”coffret”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”広島県 福山市三吉町4-13-15 1階”',
#   '””',
#   '””',
#   '””',
#   '”S001419199”',
#   '””',
#   '””',
#   '”coffret”',
#   '”根本由貴”',
#   '”佐川急便/千葉物流センタ01///BG”',
#   '””',
#   '”根本由貴”',
#   '”様”',
#   '7200031',
#   '”広島県 福山市三吉町4-13-15”',
#   '”1階”',
#   '”0849266068”',
#   '”0849266068”',
#   '””',
#   '””',
#   '””',
#   '”coffret@clock.ocn.ne.jp”',
#   '”833”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/440”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”TW-0038N”',
#   '”4562298171115”',
#   '””',
#   '”アクアナックス 300ml”',
#   '””',
#   '””',
#   '””',
#   '”2”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'East'],
#  ['2001772740',
#   '””',
#   '”2020/04/15 07:51:26”',
#   '”2020/04/15”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”coffret”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”広島県 福山市三吉町4-13-15 1階”',
#   '””',
#   '””',
#   '””',
#   '”S001419199”',
#   '””',
#   '””',
#   '”coffret”',
#   '”根本由貴”',
#   '”佐川急便/千葉物流センタ01///BG”',
#   '””',
#   '”根本由貴”',
#   '”様”',
#   '7200031',
#   '”広島県 福山市三吉町4-13-15”',
#   '”1階”',
#   '”0849266068”',
#   '”0849266068”',
#   '””',
#   '””',
#   '””',
#   '”coffret@clock.ocn.ne.jp”',
#   '”833”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/440”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”ZW-0685P”',
#   '”4560441266213”',
#   '””',
#   '”シャンプー用フェイスシートSP（100枚入り）”',
#   '””',
#   '””',
#   '””',
#   '”5”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'West'],
#  ['2001772740',
#   '””',
#   '”2020/04/15 07:51:26”',
#   '”2020/04/15”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”coffret”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”広島県 福山市三吉町4-13-15 1階”',
#   '””',
#   '””',
#   '””',
#   '”S001419199”',
#   '””',
#   '””',
#   '”coffret”',
#   '”根本由貴”',
#   '”佐川急便/千葉物流センタ01///BG”',
#   '””',
#   '”根本由貴”',
#   '”様”',
#   '7200031',
#   '”広島県 福山市三吉町4-13-15”',
#   '”1階”',
#   '”0849266068”',
#   '”0849266068”',
#   '””',
#   '””',
#   '””',
#   '”coffret@clock.ocn.ne.jp”',
#   '”833”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/440”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”TB-0169P”',
#   '”4560441259246”',
#   '””',
#   '”ECOパイル地タオル 34×85cm 12枚入り（ブラック）”',
#   '””',
#   '””',
#   '””',
#   '”2”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'East'],
#  ['2001772550',
#   '””',
#   '”2020/04/15 00:00:40”',
#   '”2020/04/15”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”Nagel_Lottie”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”神奈川県 横浜市港北区錦が丘24-7-2”',
#   '””',
#   '””',
#   '””',
#   '”S001419098”',
#   '””',
#   '””',
#   '”Nagel_Lottie”',
#   '”熊谷 恭子”',
#   '”佐川急便/千葉物流センタ01///BG”',
#   '””',
#   '”熊谷 恭子”',
#   '”様”',
#   '2220013',
#   '”神奈川県 横浜市港北区錦が丘24-7-2”',
#   '””',
#   '”08095137884”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”kyotaro48@gmail.com”',
#   '”223”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/312”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”118950”',
#   '”4560151555355”',
#   '””',
#   '”カルジェル カルガード 600ml”',
#   '””',
#   '””',
#   '””',
#   '”1”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'East'],
#  ['2001772550',
#   '””',
#   '”2020/04/15 00:00:40”',
#   '”2020/04/15”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”Nagel_Lottie”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”神奈川県 横浜市港北区錦が丘24-7-2”',
#   '””',
#   '””',
#   '””',
#   '”S001419098”',
#   '””',
#   '””',
#   '”Nagel_Lottie”',
#   '”熊谷 恭子”',
#   '”佐川急便/千葉物流センタ01///BG”',
#   '””',
#   '”熊谷 恭子”',
#   '”様”',
#   '2220013',
#   '”神奈川県 横浜市港北区錦が丘24-7-2”',
#   '””',
#   '”08095137884”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”kyotaro48@gmail.com”',
#   '”223”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/312”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”118950”',
#   '”4560151555355”',
#   '””',
#   '”カルジェル カルガード 600ml”',
#   '””',
#   '””',
#   '””',
#   '”1”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'West'],
#  ['2001772712',
#   '””',
#   '”2020/04/15 04:32:50”',
#   '”2020/04/15”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”株式会社Amazio”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”神奈川県 相模原市中央区淵野辺4-1-20”',
#   '””',
#   '””',
#   '””',
#   '”S001419170”',
#   '””',
#   '””',
#   '”株式会社Amazio”',
#   '”松永篤”',
#   '”佐川急便/千葉物流センタ01///BG”',
#   '””',
#   '”松永篤”',
#   '”様”',
#   '2520206',
#   '”神奈川県 相模原市中央区淵野辺4-1-20”',
#   '””',
#   '”080-6687-2553”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”amatsunaga42@gmail.com”',
#   '”756”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/312”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”101366”',
#   '”4589747974707”',
#   '””',
#   '”F-843スツールⅡ（お掃除キャスター仕様）ブラウン”',
#   '””',
#   '””',
#   '””',
#   '”2”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”1年”',
#   '””',
#   '””',
#   '””',
#   True,
#   'West'],
#  ['2001772755',
#   '””',
#   '”2020/04/15 08:12:38”',
#   '”2020/04/15”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BarBer kayama”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”神奈川県 川崎市宮前区宮崎1-4-15”',
#   '””',
#   '””',
#   '””',
#   '”S001419214”',
#   '””',
#   '””',
#   '”BarBer kayama”',
#   '”嘉山義則”',
#   '”佐川急便/千葉物流センタ01/23528//BG”',
#   '””',
#   '”嘉山義則”',
#   '”様”',
#   '2160033',
#   '”神奈川県 川崎市宮前区宮崎1-4-15”',
#   '””',
#   '”07055855757”',
#   '”0448541938”',
#   '”2139”',
#   '””',
#   '””',
#   '”info@bb-kayama.jp”',
#   '”342”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/312”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”ZY-0049N”',
#   '”4981104350184”',
#   '””',
#   '”YSスプレイヤー 220ml レッド”',
#   '””',
#   '””',
#   '””',
#   '”1”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'West'],
#  ['2001772755',
#   '””',
#   '”2020/04/15 08:12:38”',
#   '”2020/04/15”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BarBer kayama”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”神奈川県 川崎市宮前区宮崎1-4-15”',
#   '””',
#   '””',
#   '””',
#   '”S001419214”',
#   '””',
#   '””',
#   '”BarBer kayama”',
#   '”嘉山義則”',
#   '”佐川急便/千葉物流センタ01/23528//BG”',
#   '””',
#   '”嘉山義則”',
#   '”様”',
#   '2160033',
#   '”神奈川県 川崎市宮前区宮崎1-4-15”',
#   '””',
#   '”07055855757”',
#   '”0448541938”',
#   '”2139”',
#   '””',
#   '””',
#   '”info@bb-kayama.jp”',
#   '”342”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/312”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”ZY-0051N”',
#   '”4981104350177”',
#   '””',
#   '”YSスプレイヤー 220ml ブルー”',
#   '””',
#   '””',
#   '””',
#   '”1”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'East'],
#  ['2001772755',
#   '””',
#   '”2020/04/15 08:12:38”',
#   '”2020/04/15”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BarBer kayama”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”神奈川県 川崎市宮前区宮崎1-4-15”',
#   '””',
#   '””',
#   '””',
#   '”S001419214”',
#   '””',
#   '””',
#   '”BarBer kayama”',
#   '”嘉山義則”',
#   '”佐川急便/千葉物流センタ01/23528//BG”',
#   '””',
#   '”嘉山義則”',
#   '”様”',
#   '2160033',
#   '”神奈川県 川崎市宮前区宮崎1-4-15”',
#   '””',
#   '”07055855757”',
#   '”0448541938”',
#   '”2139”',
#   '””',
#   '””',
#   '”info@bb-kayama.jp”',
#   '”342”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/312”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”ZK-0078N”',
#   '”4560274351933”',
#   '””',
#   '”シャンプーレボリューションEXE （サイドシャンプー用/シャンプークッション）”',
#   '””',
#   '””',
#   '””',
#   '”1”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'East'],
#  ['2001772755',
#   '””',
#   '”2020/04/15 08:12:38”',
#   '”2020/04/15”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BarBer kayama”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”神奈川県 川崎市宮前区宮崎1-4-15”',
#   '””',
#   '””',
#   '””',
#   '”S001419214”',
#   '””',
#   '””',
#   '”BarBer kayama”',
#   '”嘉山義則”',
#   '”佐川急便/千葉物流センタ01/23528//BG”',
#   '””',
#   '”嘉山義則”',
#   '”様”',
#   '2160033',
#   '”神奈川県 川崎市宮前区宮崎1-4-15”',
#   '””',
#   '”07055855757”',
#   '”0448541938”',
#   '”2139”',
#   '””',
#   '””',
#   '”info@bb-kayama.jp”',
#   '”342”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/312”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”ZK-0078N”',
#   '”4560274351933”',
#   '””',
#   '”シャンプーレボリューションEXE （サイドシャンプー用/シャンプークッション）”',
#   '””',
#   '””',
#   '””',
#   '”3”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'West'],
#  ['2001772755',
#   '””',
#   '”2020/04/15 08:12:38”',
#   '”2020/04/15”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BarBer kayama”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”神奈川県 川崎市宮前区宮崎1-4-15”',
#   '””',
#   '””',
#   '””',
#   '”S001419214”',
#   '””',
#   '””',
#   '”BarBer kayama”',
#   '”嘉山義則”',
#   '”佐川急便/千葉物流センタ01/23528//BG”',
#   '””',
#   '”嘉山義則”',
#   '”様”',
#   '2160033',
#   '”神奈川県 川崎市宮前区宮崎1-4-15”',
#   '””',
#   '”07055855757”',
#   '”0448541938”',
#   '”2139”',
#   '””',
#   '””',
#   '”info@bb-kayama.jp”',
#   '”342”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/312”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”ZY-0054N”',
#   '”4981104352188”',
#   '””',
#   '”YSスプレイヤー 220ml ピンク”',
#   '””',
#   '””',
#   '””',
#   '”1”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'East'],
#  ['2001772755',
#   '””',
#   '”2020/04/15 08:12:38”',
#   '”2020/04/15”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BarBer kayama”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”神奈川県 川崎市宮前区宮崎1-4-15”',
#   '””',
#   '””',
#   '””',
#   '”S001419214”',
#   '””',
#   '””',
#   '”BarBer kayama”',
#   '”嘉山義則”',
#   '”佐川急便/千葉物流センタ01/23528//BG”',
#   '””',
#   '”嘉山義則”',
#   '”様”',
#   '2160033',
#   '”神奈川県 川崎市宮前区宮崎1-4-15”',
#   '””',
#   '”07055855757”',
#   '”0448541938”',
#   '”2139”',
#   '””',
#   '””',
#   '”info@bb-kayama.jp”',
#   '”342”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”/312”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”ZY-0054N”',
#   '”4981104352188”',
#   '””',
#   '”YSスプレイヤー 220ml ピンク”',
#   '””',
#   '””',
#   '””',
#   '”1”',
#   '”PC”',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '””',
#   '”BG00”',
#   '”なし”',
#   '””',
#   '””',
#   '””',
#   True,
#   'West']]

# %%
field = ["Shipping_Order_No","Voucher_Class","Order_Date","Delivery_Date","Planed_Ship_Date","DC_Code","DC_Name","Customer_Code","Customer_Name1","Customer_Name2","Data_11","Data_12","Data_13","Data_14","Customer_Zip_Code","Customer_address1","Customer_address2","Customer_TEL","Customer_FAX","Order_No","Transport_Company","Receiver_Code","Receiver_Name1","Receiver_Name2","Data_25","Data_26","Data_27","Data_28","Receiver_Zip_Code","Receiver_address1","Receiver_address2","Receiver_TEL","Receiver_FAX","Consumption_TAX","Data_35","Data_36","Mail_address","Point","Data_39","SAP_Shipping_No","Data_41","Working_Condition","Balance","Data_44","Data_45","Data_46","Data_47","Update_date","Detail_No","Data_50","Stock_No","BarCode","Location","Description1","Description2","Pcs_Per_case","Case_No","Quantity","Units","Lot1","Lot2","Status_Code","Status","Data_64","Data_65","Data_66","Warranty","Data_68","Data_69","Detail_Update_date","Availability","EasrOrWest"]

# %%
df_complete_orders = pd.DataFrame(lComplete_orders, columns = field)
df_complete_orders
# Out:
#    Shipping_Order_No Voucher_Class             Order_Date Delivery_Date  \
# 0         2001771962            ””  ”2020/04/14 18:22:16”  ”2020/04/14”
# 1         2001771962            ””  ”2020/04/14 18:22:16”  ”2020/04/14”
# 2         2001771962            ””  ”2020/04/14 18:22:16”  ”2020/04/14”
# 3         2001771962            ””  ”2020/04/14 18:22:16”  ”2020/04/14”
# 4         2001771962            ””  ”2020/04/14 18:22:16”  ”2020/04/14”
# 5         2001771962            ””  ”2020/04/14 18:22:16”  ”2020/04/14”
# 6         2001771962            ””  ”2020/04/14 18:22:16”  ”2020/04/14”
# 7         2001771962            ””  ”2020/04/14 18:22:16”  ”2020/04/14”
# 8         2001771962            ””  ”2020/04/14 18:22:16”  ”2020/04/14”
# 9         2001771984            ””  ”2020/04/14 18:49:11”  ”2020/04/14”
# 10        2001771984            ””  ”2020/04/14 18:49:11”  ”2020/04/14”
# 11        2001771999            ””  ”2020/04/14 19:01:14”  ”2020/04/14”
# 12        2001772059            ””  ”2020/04/14 19:57:02”  ”2020/04/14”
# 13        2001772463            ””  ”2020/04/14 22:48:37”  ”2020/04/14”
# 14        2001772463            ””  ”2020/04/14 22:48:37”  ”2020/04/14”
# 15        2001772492            ””  ”2020/04/14 22:59:57”  ”2020/04/14”
# 16        2001772492            ””  ”2020/04/14 22:59:57”  ”2020/04/14”
# 17        2001772492            ””  ”2020/04/14 22:59:57”  ”2020/04/14”
# 18        2001772492            ””  ”2020/04/14 22:59:57”  ”2020/04/14”
# 19        2001772492            ””  ”2020/04/14 22:59:57”  ”2020/04/14”
# 20        2001772492            ””  ”2020/04/14 22:59:57”  ”2020/04/14”
# 21        2001772492            ””  ”2020/04/14 22:59:57”  ”2020/04/14”
# 22        2001772492            ””  ”2020/04/14 22:59:57”  ”2020/04/14”
# 23        2001772492            ””  ”2020/04/14 22:59:57”  ”2020/04/14”
# 24        2001772492            ””  ”2020/04/14 22:59:57”  ”2020/04/14”
# 25        2001772492            ””  ”2020/04/14 22:59:57”  ”2020/04/14”
# 26        2001772004            ””  ”2020/04/14 19:09:44”  ”2020/04/14”
# 27        2001772004            ””  ”2020/04/14 19:09:44”  ”2020/04/14”
# 28        2001772004            ””  ”2020/04/14 19:09:44”  ”2020/04/14”
# 29        2001772007            ””  ”2020/04/14 19:12:33”  ”2020/04/14”
# 30        2001772007            ””  ”2020/04/14 19:12:33”  ”2020/04/14”
# 31        2001772085            ””  ”2020/04/14 20:19:48”  ”2020/04/14”
# 32        2001772163            ””  ”2020/04/14 21:29:28”  ”2020/04/14”
# 33        2001772163            ””  ”2020/04/14 21:29:28”  ”2020/04/14”
# 34        2001772163            ””  ”2020/04/14 21:29:28”  ”2020/04/14”
# 35        2001772163            ””  ”2020/04/14 21:29:28”  ”2020/04/14”
# 36        2001772163            ””  ”2020/04/14 21:29:28”  ”2020/04/14”
# 37        2001772163            ””  ”2020/04/14 21:29:28”  ”2020/04/14”
# 38        2001772163            ””  ”2020/04/14 21:29:28”  ”2020/04/14”
# 39        2001772163            ””  ”2020/04/14 21:29:28”  ”2020/04/14”
# 40        2001772740            ””  ”2020/04/15 07:51:26”  ”2020/04/15”
# 41        2001772740            ””  ”2020/04/15 07:51:26”  ”2020/04/15”
# 42        2001772740            ””  ”2020/04/15 07:51:26”  ”2020/04/15”
# 43        2001772550            ””  ”2020/04/15 00:00:40”  ”2020/04/15”
# 44        2001772550            ””  ”2020/04/15 00:00:40”  ”2020/04/15”
# 45        2001772712            ””  ”2020/04/15 04:32:50”  ”2020/04/15”
# 46        2001772755            ””  ”2020/04/15 08:12:38”  ”2020/04/15”
# 47        2001772755            ””  ”2020/04/15 08:12:38”  ”2020/04/15”
# 48        2001772755            ””  ”2020/04/15 08:12:38”  ”2020/04/15”
# 49        2001772755            ””  ”2020/04/15 08:12:38”  ”2020/04/15”
# 50        2001772755            ””  ”2020/04/15 08:12:38”  ”2020/04/15”
# 51        2001772755            ””  ”2020/04/15 08:12:38”  ”2020/04/15”
#
#    Planed_Ship_Date DC_Code DC_Name Customer_Code   Customer_Name1  \
# 0                ””      ””      ””            ””      ”Sea　gull.”
# 1                ””      ””      ””            ””      ”Sea　gull.”
# 2                ””      ””      ””            ””      ”Sea　gull.”
# 3                ””      ””      ””            ””      ”Sea　gull.”
# 4                ””      ””      ””            ””      ”Sea　gull.”
# 5                ””      ””      ””            ””      ”Sea　gull.”
# 6                ””      ””      ””            ””      ”Sea　gull.”
# 7                ””      ””      ””            ””      ”Sea　gull.”
# 8                ””      ””      ””            ””      ”Sea　gull.”
# 9                ””      ””      ””            ””           ”シャルム”
# 10               ””      ””      ””            ””           ”シャルム”
# 11               ””      ””      ””            ””   ”ボディケア　縁-えにし-”
# 12               ””      ””      ””            ””          ”庄司 悦子”
# 13               ””      ””      ””            ””            ”悠心堂”
# 14               ””      ””      ””            ””            ”悠心堂”
# 15               ””      ””      ””            ””         ”CLOVER”
# 16               ””      ””      ””            ””         ”CLOVER”
# 17               ””      ””      ””            ””         ”CLOVER”
# 18               ””      ””      ””            ””         ”CLOVER”
# 19               ””      ””      ””            ””         ”CLOVER”
# 20               ””      ””      ””            ””         ”CLOVER”
# 21               ””      ””      ””            ””         ”CLOVER”
# 22               ””      ””      ””            ””         ”CLOVER”
# 23               ””      ””      ””            ””         ”CLOVER”
# 24               ””      ””      ””            ””         ”CLOVER”
# 25               ””      ””      ””            ””         ”CLOVER”
# 26               ””      ””      ””            ””           ”阪本恵美”
# 27               ””      ””      ””            ””           ”阪本恵美”
# 28               ””      ””      ””            ””           ”阪本恵美”
# 29               ””      ””      ””            ””      ”I&B　NaFaS”
# 30               ””      ””      ””            ””      ”I&B　NaFaS”
# 31               ””      ””      ””            ””          ”小林ひろみ”
# 32               ””      ””      ””            ””          ”宮島つくみ”
# 33               ””      ””      ””            ””          ”宮島つくみ”
# 34               ””      ””      ””            ””          ”宮島つくみ”
# 35               ””      ””      ””            ””          ”宮島つくみ”
# 36               ””      ””      ””            ””          ”宮島つくみ”
# 37               ””      ””      ””            ””          ”宮島つくみ”
# 38               ””      ””      ””            ””          ”宮島つくみ”
# 39               ””      ””      ””            ””          ”宮島つくみ”
# 40               ””      ””      ””            ””        ”coffret”
# 41               ””      ””      ””            ””        ”coffret”
# 42               ””      ””      ””            ””        ”coffret”
# 43               ””      ””      ””            ””   ”Nagel_Lottie”
# 44               ””      ””      ””            ””   ”Nagel_Lottie”
# 45               ””      ””      ””            ””     ”株式会社Amazio”
# 46               ””      ””      ””            ””  ”BarBer kayama”
# 47               ””      ””      ””            ””  ”BarBer kayama”
# 48               ””      ””      ””            ””  ”BarBer kayama”
# 49               ””      ””      ””            ””  ”BarBer kayama”
# 50               ””      ””      ””            ””  ”BarBer kayama”
# 51               ””      ””      ””            ””  ”BarBer kayama”
#
#    Customer_Name2  ... Status Data_64 Data_65 Data_66 Warranty Data_68  \
# 0              ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 1              ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 2              ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 3              ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 4              ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 5              ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 6              ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 7              ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 8              ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 9              ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 10             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 11             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 12             ””  ...     ””      ””      ””  ”BG00”     ”1年”      ””
# 13             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 14             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 15             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 16             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 17             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 18             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 19             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 20             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 21             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 22             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 23             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 24             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 25             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 26             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 27             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 28             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 29             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 30             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 31             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 32             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 33             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 34             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 35             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 36             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 37             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 38             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 39             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 40             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 41             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 42             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 43             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 44             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 45             ””  ...     ””      ””      ””  ”BG00”     ”1年”      ””
# 46             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 47             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 48             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 49             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 50             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 51             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
#
#    Data_69 Detail_Update_date Availability EasrOrWest
# 0       ””                 ””         True       West
# 1       ””                 ””         True       West
# 2       ””                 ””         True       West
# 3       ””                 ””         True       West
# 4       ””                 ””         True       West
# 5       ””                 ””         True       West
# 6       ””                 ””         True       West
# 7       ””                 ””         True       West
# 8       ””                 ””         True       West
# 9       ””                 ””         True       East
# 10      ””                 ””         True       East
# 11      ””                 ””         True       West
# 12      ””                 ””         True       East
# 13      ””                 ””         True       East
# 14      ””                 ””         True       West
# 15      ””                 ””         True       East
# 16      ””                 ””         True       East
# 17      ””                 ””         True       East
# 18      ””                 ””         True       East
# 19      ””                 ””         True       West
# 20      ””                 ””         True       East
# 21      ””                 ””         True       East
# 22      ””                 ””         True       East
# 23      ””                 ””         True       East
# 24      ””                 ””         True       East
# 25      ””                 ””         True       West
# 26      ””                 ””         True       East
# 27      ””                 ””         True       East
# 28      ””                 ””         True       East
# 29      ””                 ””         True       West
# 30      ””                 ””         True       West
# 31      ””                 ””         True       East
# 32      ””                 ””         True       East
# 33      ””                 ””         True       West
# 34      ””                 ””         True       West
# 35      ””                 ””         True       East
# 36      ””                 ””         True       East
# 37      ””                 ””         True       East
# 38      ””                 ””         True       East
# 39      ””                 ””         True       West
# 40      ””                 ””         True       East
# 41      ””                 ””         True       West
# 42      ””                 ””         True       East
# 43      ””                 ””         True       East
# 44      ””                 ””         True       West
# 45      ””                 ””         True       West
# 46      ””                 ””         True       West
# 47      ””                 ””         True       East
# 48      ””                 ””         True       East
# 49      ””                 ””         True       West
# 50      ””                 ””         True       East
# 51      ””                 ””         True       West
#
# [52 rows x 72 columns]

# %%
df_East = df_complete_orders.loc[df_complete_orders["EasrOrWest"] == "East"]
df_East = df_East.reset_index().drop(columns=['index'])

# %%
df_West = df_complete_orders.loc[df_complete_orders['EasrOrWest'] == 'West']
df_West = df_West.reset_index().drop(columns=['index'])

# %%
df_East
# Out:
#    Shipping_Order_No Voucher_Class             Order_Date Delivery_Date  \
# 0         2001771984            ””  ”2020/04/14 18:49:11”  ”2020/04/14”
# 1         2001771984            ””  ”2020/04/14 18:49:11”  ”2020/04/14”
# 2         2001772059            ””  ”2020/04/14 19:57:02”  ”2020/04/14”
# 3         2001772463            ””  ”2020/04/14 22:48:37”  ”2020/04/14”
# 4         2001772492            ””  ”2020/04/14 22:59:57”  ”2020/04/14”
# 5         2001772492            ””  ”2020/04/14 22:59:57”  ”2020/04/14”
# 6         2001772492            ””  ”2020/04/14 22:59:57”  ”2020/04/14”
# 7         2001772492            ””  ”2020/04/14 22:59:57”  ”2020/04/14”
# 8         2001772492            ””  ”2020/04/14 22:59:57”  ”2020/04/14”
# 9         2001772492            ””  ”2020/04/14 22:59:57”  ”2020/04/14”
# 10        2001772492            ””  ”2020/04/14 22:59:57”  ”2020/04/14”
# 11        2001772492            ””  ”2020/04/14 22:59:57”  ”2020/04/14”
# 12        2001772492            ””  ”2020/04/14 22:59:57”  ”2020/04/14”
# 13        2001772004            ””  ”2020/04/14 19:09:44”  ”2020/04/14”
# 14        2001772004            ””  ”2020/04/14 19:09:44”  ”2020/04/14”
# 15        2001772004            ””  ”2020/04/14 19:09:44”  ”2020/04/14”
# 16        2001772085            ””  ”2020/04/14 20:19:48”  ”2020/04/14”
# 17        2001772163            ””  ”2020/04/14 21:29:28”  ”2020/04/14”
# 18        2001772163            ””  ”2020/04/14 21:29:28”  ”2020/04/14”
# 19        2001772163            ””  ”2020/04/14 21:29:28”  ”2020/04/14”
# 20        2001772163            ””  ”2020/04/14 21:29:28”  ”2020/04/14”
# 21        2001772163            ””  ”2020/04/14 21:29:28”  ”2020/04/14”
# 22        2001772740            ””  ”2020/04/15 07:51:26”  ”2020/04/15”
# 23        2001772740            ””  ”2020/04/15 07:51:26”  ”2020/04/15”
# 24        2001772550            ””  ”2020/04/15 00:00:40”  ”2020/04/15”
# 25        2001772755            ””  ”2020/04/15 08:12:38”  ”2020/04/15”
# 26        2001772755            ””  ”2020/04/15 08:12:38”  ”2020/04/15”
# 27        2001772755            ””  ”2020/04/15 08:12:38”  ”2020/04/15”
#
#    Planed_Ship_Date DC_Code DC_Name Customer_Code   Customer_Name1  \
# 0                ””      ””      ””            ””           ”シャルム”
# 1                ””      ””      ””            ””           ”シャルム”
# 2                ””      ””      ””            ””          ”庄司 悦子”
# 3                ””      ””      ””            ””            ”悠心堂”
# 4                ””      ””      ””            ””         ”CLOVER”
# 5                ””      ””      ””            ””         ”CLOVER”
# 6                ””      ””      ””            ””         ”CLOVER”
# 7                ””      ””      ””            ””         ”CLOVER”
# 8                ””      ””      ””            ””         ”CLOVER”
# 9                ””      ””      ””            ””         ”CLOVER”
# 10               ””      ””      ””            ””         ”CLOVER”
# 11               ””      ””      ””            ””         ”CLOVER”
# 12               ””      ””      ””            ””         ”CLOVER”
# 13               ””      ””      ””            ””           ”阪本恵美”
# 14               ””      ””      ””            ””           ”阪本恵美”
# 15               ””      ””      ””            ””           ”阪本恵美”
# 16               ””      ””      ””            ””          ”小林ひろみ”
# 17               ””      ””      ””            ””          ”宮島つくみ”
# 18               ””      ””      ””            ””          ”宮島つくみ”
# 19               ””      ””      ””            ””          ”宮島つくみ”
# 20               ””      ””      ””            ””          ”宮島つくみ”
# 21               ””      ””      ””            ””          ”宮島つくみ”
# 22               ””      ””      ””            ””        ”coffret”
# 23               ””      ””      ””            ””        ”coffret”
# 24               ””      ””      ””            ””   ”Nagel_Lottie”
# 25               ””      ””      ””            ””  ”BarBer kayama”
# 26               ””      ””      ””            ””  ”BarBer kayama”
# 27               ””      ””      ””            ””  ”BarBer kayama”
#
#    Customer_Name2  ... Status Data_64 Data_65 Data_66 Warranty Data_68  \
# 0              ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 1              ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 2              ””  ...     ””      ””      ””  ”BG00”     ”1年”      ””
# 3              ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 4              ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 5              ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 6              ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 7              ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 8              ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 9              ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 10             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 11             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 12             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 13             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 14             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 15             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 16             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 17             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 18             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 19             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 20             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 21             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 22             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 23             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 24             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 25             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 26             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 27             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
#
#    Data_69 Detail_Update_date Availability EasrOrWest
# 0       ””                 ””         True       East
# 1       ””                 ””         True       East
# 2       ””                 ””         True       East
# 3       ””                 ””         True       East
# 4       ””                 ””         True       East
# 5       ””                 ””         True       East
# 6       ””                 ””         True       East
# 7       ””                 ””         True       East
# 8       ””                 ””         True       East
# 9       ””                 ””         True       East
# 10      ””                 ””         True       East
# 11      ””                 ””         True       East
# 12      ””                 ””         True       East
# 13      ””                 ””         True       East
# 14      ””                 ””         True       East
# 15      ””                 ””         True       East
# 16      ””                 ””         True       East
# 17      ””                 ””         True       East
# 18      ””                 ””         True       East
# 19      ””                 ””         True       East
# 20      ””                 ””         True       East
# 21      ””                 ””         True       East
# 22      ””                 ””         True       East
# 23      ””                 ””         True       East
# 24      ””                 ””         True       East
# 25      ””                 ””         True       East
# 26      ””                 ””         True       East
# 27      ””                 ””         True       East
#
# [28 rows x 72 columns]

# %%
df_West
# Out:
#    Shipping_Order_No Voucher_Class             Order_Date Delivery_Date  \
# 0         2001771962            ””  ”2020/04/14 18:22:16”  ”2020/04/14”
# 1         2001771962            ””  ”2020/04/14 18:22:16”  ”2020/04/14”
# 2         2001771962            ””  ”2020/04/14 18:22:16”  ”2020/04/14”
# 3         2001771962            ””  ”2020/04/14 18:22:16”  ”2020/04/14”
# 4         2001771962            ””  ”2020/04/14 18:22:16”  ”2020/04/14”
# 5         2001771962            ””  ”2020/04/14 18:22:16”  ”2020/04/14”
# 6         2001771962            ””  ”2020/04/14 18:22:16”  ”2020/04/14”
# 7         2001771962            ””  ”2020/04/14 18:22:16”  ”2020/04/14”
# 8         2001771962            ””  ”2020/04/14 18:22:16”  ”2020/04/14”
# 9         2001771999            ””  ”2020/04/14 19:01:14”  ”2020/04/14”
# 10        2001772463            ””  ”2020/04/14 22:48:37”  ”2020/04/14”
# 11        2001772492            ””  ”2020/04/14 22:59:57”  ”2020/04/14”
# 12        2001772492            ””  ”2020/04/14 22:59:57”  ”2020/04/14”
# 13        2001772007            ””  ”2020/04/14 19:12:33”  ”2020/04/14”
# 14        2001772007            ””  ”2020/04/14 19:12:33”  ”2020/04/14”
# 15        2001772163            ””  ”2020/04/14 21:29:28”  ”2020/04/14”
# 16        2001772163            ””  ”2020/04/14 21:29:28”  ”2020/04/14”
# 17        2001772163            ””  ”2020/04/14 21:29:28”  ”2020/04/14”
# 18        2001772740            ””  ”2020/04/15 07:51:26”  ”2020/04/15”
# 19        2001772550            ””  ”2020/04/15 00:00:40”  ”2020/04/15”
# 20        2001772712            ””  ”2020/04/15 04:32:50”  ”2020/04/15”
# 21        2001772755            ””  ”2020/04/15 08:12:38”  ”2020/04/15”
# 22        2001772755            ””  ”2020/04/15 08:12:38”  ”2020/04/15”
# 23        2001772755            ””  ”2020/04/15 08:12:38”  ”2020/04/15”
#
#    Planed_Ship_Date DC_Code DC_Name Customer_Code   Customer_Name1  \
# 0                ””      ””      ””            ””      ”Sea　gull.”
# 1                ””      ””      ””            ””      ”Sea　gull.”
# 2                ””      ””      ””            ””      ”Sea　gull.”
# 3                ””      ””      ””            ””      ”Sea　gull.”
# 4                ””      ””      ””            ””      ”Sea　gull.”
# 5                ””      ””      ””            ””      ”Sea　gull.”
# 6                ””      ””      ””            ””      ”Sea　gull.”
# 7                ””      ””      ””            ””      ”Sea　gull.”
# 8                ””      ””      ””            ””      ”Sea　gull.”
# 9                ””      ””      ””            ””   ”ボディケア　縁-えにし-”
# 10               ””      ””      ””            ””            ”悠心堂”
# 11               ””      ””      ””            ””         ”CLOVER”
# 12               ””      ””      ””            ””         ”CLOVER”
# 13               ””      ””      ””            ””      ”I&B　NaFaS”
# 14               ””      ””      ””            ””      ”I&B　NaFaS”
# 15               ””      ””      ””            ””          ”宮島つくみ”
# 16               ””      ””      ””            ””          ”宮島つくみ”
# 17               ””      ””      ””            ””          ”宮島つくみ”
# 18               ””      ””      ””            ””        ”coffret”
# 19               ””      ””      ””            ””   ”Nagel_Lottie”
# 20               ””      ””      ””            ””     ”株式会社Amazio”
# 21               ””      ””      ””            ””  ”BarBer kayama”
# 22               ””      ””      ””            ””  ”BarBer kayama”
# 23               ””      ””      ””            ””  ”BarBer kayama”
#
#    Customer_Name2  ... Status Data_64 Data_65 Data_66 Warranty Data_68  \
# 0              ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 1              ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 2              ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 3              ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 4              ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 5              ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 6              ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 7              ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 8              ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 9              ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 10             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 11             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 12             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 13             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 14             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 15             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 16             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 17             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 18             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 19             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 20             ””  ...     ””      ””      ””  ”BG00”     ”1年”      ””
# 21             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 22             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
# 23             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””
#
#    Data_69 Detail_Update_date Availability EasrOrWest
# 0       ””                 ””         True       West
# 1       ””                 ””         True       West
# 2       ””                 ””         True       West
# 3       ””                 ””         True       West
# 4       ””                 ””         True       West
# 5       ””                 ””         True       West
# 6       ””                 ””         True       West
# 7       ””                 ””         True       West
# 8       ””                 ””         True       West
# 9       ””                 ””         True       West
# 10      ””                 ””         True       West
# 11      ””                 ””         True       West
# 12      ””                 ””         True       West
# 13      ””                 ””         True       West
# 14      ””                 ””         True       West
# 15      ””                 ””         True       West
# 16      ””                 ””         True       West
# 17      ””                 ””         True       West
# 18      ””                 ””         True       West
# 19      ””                 ””         True       West
# 20      ””                 ””         True       West
# 21      ””                 ””         True       West
# 22      ””                 ””         True       West
# 23      ””                 ””         True       West
#
# [24 rows x 72 columns]

# %%
xx="hello"
xx = '”' + xx + '”'
xx
# Out:
# '”hello”'

# %%
lIncomplete_orders = list()
for order in Incomplete_orders:
    for i in range(len(order.items)):
        order.order_num = '”' + order.order_num + '”'
        order.zipcode = '”' + order.zipcode + '”'
        order.items[i][0] = '”' + order.items[i][0] + '”'
        order.items[i][1] = '”' + str(order.items[i][1]) + '”'
        temp = [order.order_num, \
                order.items[i][4][0],order.items[i][4][1],order.items[i][4][2],order.items[i][4][3],\
                order.items[i][4][4],order.items[i][4][5],order.items[i][4][6],order.items[i][4][7],\
                order.items[i][4][8],order.items[i][4][9],order.items[i][4][10],order.items[i][4][11],\
                order.items[i][4][12],order.items[i][4][13],order.items[i][4][14],order.items[i][4][15],\
                order.items[i][4][16],order.items[i][4][17],order.items[i][4][18],order.items[i][4][19],\
                order.items[i][4][20],order.items[i][4][21],order.items[i][4][22],order.items[i][4][23],\
                order.items[i][4][24],order.items[i][4][25],order.items[i][4][26],order.zipcode,\
                order.items[i][4][27],order.items[i][4][28],order.items[i][4][29],order.items[i][4][30],\
                order.items[i][4][31],order.items[i][4][32],order.items[i][4][33],order.items[i][4][34],\
                order.items[i][4][35],order.items[i][4][36],order.items[i][4][37],order.items[i][4][38],\
                order.items[i][4][39],order.items[i][4][40],order.items[i][4][41],order.items[i][4][42],\
                order.items[i][4][43],order.items[i][4][44],order.items[i][4][45],order.items[i][4][46],\
                order.items[i][4][47],order.items[i][0],order.items[i][4][48],order.items[i][4][49],\
                order.items[i][4][50],order.items[i][4][51],order.items[i][4][52],order.items[i][4][53],\
                order.items[i][1],order.items[i][4][54],order.items[i][4][55],order.items[i][4][56],\
                order.items[i][4][57],order.items[i][4][58],order.items[i][4][59],order.items[i][4][60],\
                order.items[i][4][61],order.items[i][4][62],order.items[i][4][63],order.items[i][4][64],\
                order.items[i][4][65],order.items[i][2], order.items[i][3]]
        lIncomplete_orders.append(temp)

# %%
df_incomplete_orders = pd.DataFrame(lIncomplete_orders, columns = field)
df_incomplete_orders
# Out:
#   Shipping_Order_No Voucher_Class             Order_Date Delivery_Date  \
# 0      ”2001769876”            ””  ”2020/04/13 22:07:52”  ”2020/04/13”
# 1      ”2001772707”            ””  ”2020/04/15 03:24:49”  ”2020/04/15”
# 2    ””2001772707””            ””  ”2020/04/15 03:24:49”  ”2020/04/15”
# 3      ”2001772649”            ””  ”2020/04/15 00:27:34”  ”2020/04/15”
# 4    ””2001772649””            ””  ”2020/04/15 00:27:34”  ”2020/04/15”
# 5  ”””2001772649”””            ””  ”2020/04/15 00:27:34”  ”2020/04/15”
# 6      ”2001772745”            ””  ”2020/04/15 07:55:57”  ”2020/04/15”
#
#   Planed_Ship_Date DC_Code DC_Name Customer_Code       Customer_Name1  \
# 0               ””      ””      ””            ””             ”フリーランス”
# 1               ””      ””      ””            ””                ”day”
# 2               ””      ””      ””            ””                ”day”
# 3               ””      ””      ””            ””  ”トータルボディケアサロン　Bean”
# 4               ””      ””      ””            ””  ”トータルボディケアサロン　Bean”
# 5               ””      ””      ””            ””  ”トータルボディケアサロン　Bean”
# 6               ””      ””      ””            ””               ”Aaty”
#
#   Customer_Name2  ... Status Data_64 Data_65 Data_66 Warranty Data_68 Data_69  \
# 0             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””      ””
# 1             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””      ””
# 2             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””      ””
# 3             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””      ””
# 4             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””      ””
# 5             ””  ...     ””      ””      ””  ”BG00”     ”なし”      ””      ””
# 6             ””  ...     ””      ””      ””  ”BG00”     ”1年”      ””      ””
#
#   Detail_Update_date Availability EasrOrWest
# 0                 ””        False    unknown
# 1                 ””        False    unknown
# 2                 ””        False    unknown
# 3                 ””        False    unknown
# 4                 ””         True       East
# 5                 ””        False    unknown
# 6                 ””        False    unknown
#
# [7 rows x 72 columns]

# %% [markdown]
# ______________output__________________

# %%
import datetime
dateTimeObj = datetime.datetime.now()
timestampStr = dateTimeObj.strftime("%d-%b-%Y")
timestampStr
# Out:
# '23-Apr-2020'

# %%
name_east_file = './output/East_orders' + timestampStr +'.csv'
name_east_file
# Out:
# './output/East_orders23-Apr-2020.csv'

# %%
name_west_file = './output/West_orders' + timestampStr +'.csv'
name_west_file
# Out:
# './output/West_orders23-Apr-2020.csv'

# %%
name_incom_file = './output/Incomplete_orders' + timestampStr +'.csv'

# %% [markdown]
# Adding ” to zipcode and shippingNum

# %%
df_East['Shipping_Order_No'] = '”' + df_East['Shipping_Order_No'].astype(str) + '”'
df_East['Receiver_Zip_Code'] = '”' + df_East['Receiver_Zip_Code'].astype(str) + '”'
df_West['Shipping_Order_No'] = '”' + df_West['Shipping_Order_No'].astype(str) + '”'
df_West['Receiver_Zip_Code'] = '”' + df_West['Receiver_Zip_Code'].astype(str) + '”'
df_incomplete_orders['Shipping_Order_No'] = '”' + df_incomplete_orders['Shipping_Order_No'].astype(str) + '”'
df_incomplete_orders['Receiver_Zip_Code'] = '”' + df_incomplete_orders['Receiver_Zip_Code'].astype(str) + '”'

# %% [markdown]
# Dropping West/East and Availibility

# %%
df_East = df_East.drop(columns =['Availability', 'EasrOrWest']) 
df_West = df_West.drop(columns =['Availability', 'EasrOrWest']) 
df_incomplete_orders = df_incomplete_orders.drop(columns =['Availability', 'EasrOrWest'])
# Out:
#     Shipping_Order_No Voucher_Class             Order_Date Delivery_Date  \
# 0      ””2001769876””            ””  ”2020/04/13 22:07:52”  ”2020/04/13”
# 1      ””2001772707””            ””  ”2020/04/15 03:24:49”  ”2020/04/15”
# 2    ”””2001772707”””            ””  ”2020/04/15 03:24:49”  ”2020/04/15”
# 3      ””2001772649””            ””  ”2020/04/15 00:27:34”  ”2020/04/15”
# 4    ”””2001772649”””            ””  ”2020/04/15 00:27:34”  ”2020/04/15”
# 5  ””””2001772649””””            ””  ”2020/04/15 00:27:34”  ”2020/04/15”
# 6      ””2001772745””            ””  ”2020/04/15 07:55:57”  ”2020/04/15”
#
#   Planed_Ship_Date DC_Code DC_Name Customer_Code       Customer_Name1  \
# 0               ””      ””      ””            ””             ”フリーランス”
# 1               ””      ””      ””            ””                ”day”
# 2               ””      ””      ””            ””                ”day”
# 3               ””      ””      ””            ””  ”トータルボディケアサロン　Bean”
# 4               ””      ””      ””            ””  ”トータルボディケアサロン　Bean”
# 5               ””      ””      ””            ””  ”トータルボディケアサロン　Bean”
# 6               ””      ””      ””            ””               ”Aaty”
#
#   Customer_Name2  ... Lot2 Status_Code Status Data_64 Data_65 Data_66  \
# 0             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 1             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 2             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 3             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 4             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 5             ””  ...   ””          ””     ””      ””      ””  ”BG00”
# 6             ””  ...   ””          ””     ””      ””      ””  ”BG00”
#
#   Warranty Data_68 Data_69 Detail_Update_date
# 0     ”なし”      ””      ””                 ””
# 1     ”なし”      ””      ””                 ””
# 2     ”なし”      ””      ””                 ””
# 3     ”なし”      ””      ””                 ””
# 4     ”なし”      ””      ””                 ””
# 5     ”なし”      ””      ””                 ””
# 6     ”1年”      ””      ””                 ””
#
# [7 rows x 70 columns]

# %%
df_East.to_csv(name_east_file, index=False, header=None, encoding="shift_jis_2004")

# %%
df_West.to_csv(name_west_file, index=False, header=None, encoding="shift_jis_2004")

# %%
df_incomplete_orders.to_csv(name_incom_file, index=False, header=None, encoding="shift_jis_2004")
